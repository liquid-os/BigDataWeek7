# %% [markdown]
# # Lab 7 - Textual Data Analytics
# Complete the code with TODO tag.
# ## 1. Feature Engineering
# In this exercise we will understand the functioning of TF/IDF ranking. Implement the feature engineering and its application, based on the code framework provided below.
#
# First we use textual data from Twitter.

# %%
import numpy as np
import pandas as pd
data = pd.read_csv('elonmusk_tweets.csv')
print(len(data))
data.head()
# Out:
# 2819
#                    id           created_at  \
# 0  849636868052275200  2017-04-05 14:56:29
# 1  848988730585096192  2017-04-03 20:01:01
# 2  848943072423497728  2017-04-03 16:59:35
# 3  848935705057280001  2017-04-03 16:30:19
# 4  848416049573658624  2017-04-02 06:05:23
#
#                                                 text
# 0  b'And so the robots spared humanity ... https:...
# 1  b"@ForIn2020 @waltmossberg @mims @defcon_5 Exa...
# 2      b'@waltmossberg @mims @defcon_5 Et tu, Walt?'
# 3                b'Stormy weather in Shortville ...'
# 4  b"@DaveLeeBBC @verge Coal is dying due to nat ...

# %% [markdown]
# ### 1.1. Text Normalization
# Now we need to normalize text by stemming, tokenizing, and removing stopwords.

# %%
from __future__ import print_function, division
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
nltk.download('punkt')
import string
from nltk.corpus import stopwords
import math
from collections import Counter
nltk.download('stopwords')
import pprint 
pp = pprint.PrettyPrinter(indent=4)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Pube\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Pube\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.tokenize import word_tokenize

def normalize(document):
    tokens = word_tokenize(document)
    
    text = [word for word in tokens if word.isalpha()]
    
    stemmer = PorterStemmer()
    ret = ""
    for word in text:
        ret = ret+stemmer.stem(word)+" "
    return ret

print("Stemmed Data:")
original_documents = [x.strip() for x in data['text']] 
documents = [normalize(d).split() for d in original_documents]
documents[0]
# Out:
# Stemmed Data:
# ['so', 'the', 'robot', 'spare', 'human', 'http']

# %% [markdown]
# As you can see that the normalization is still not perfect. Please feel free to improve upon (OPTIONAL), e.g. https://marcobonzanini.com/2015/03/09/mining-twitter-data-with-python-part-2/

# %% [markdown]
# ### 1.2. Implement TF-IDF
# Now you need to implement TF-IDF, including creating the vocabulary, computing term frequency, and normalizing by tf-idf weights.

# %%
# Flatten all the documents
flat_list = [word for doc in documents for word in doc]
# TODO: remove stop words from the vocabulary
stop_words = set(stopwords.words('english'))

filtered = [w for w in flat_list if not w in stop_words] 

# TODO: we take the 500 most common words only
counts = Counter(filtered)
vocabulary = [w for w in counts.most_common(500)]
print([x for x in vocabulary if x[0] == 'tesla'])
vocabulary = [x[0] for x in vocabulary]
assert len(vocabulary) == 500

#vocabulary.sort()
vocabulary[:10]
# Out:
# [('tesla', 288)]
# ['b',
#  'http',
#  'tesla',
#  'I',
#  'spacex',
#  'model',
#  'thi',
#  'amp',
#  'car',
#  'teslamotor']

# %%
def tf(vocabulary, documents):
    matrix = [0] * len(documents)
    for i, document in enumerate(documents):
        counts = Counter(document)
        matrix[i] = [0] * len(vocabulary)
        for j, term in enumerate(vocabulary):
            matrix[i][j] = counts[term]
    return matrix

tf = tf(vocabulary, documents)
np.array(vocabulary)[np.where(np.array(tf[1]) > 0)], np.array(tf[1])[np.where(np.array(tf[1]) > 0)]
# Out:
# (array(['b', 'http', 'tesla', 'exactli', 'base'], dtype='<U15'),
#  array([1, 1, 1, 1, 1]))

# %%
def idf(vocabulary, documents):
    idf = {}
    total_docs_len = len(documents)
    for word in vocabulary:
        x = 0
        for document in documents:
            if word in document:
                x += 1
        idf[word] = math.log(total_docs_len/x)
    return idf

idf_obj = idf(vocabulary, documents)

# %%
def vectorize(document, vocabulary, idf):
    vector = [0]*len(vocabulary)
    counts = Counter(document)
    print(counts)
    for i,term in enumerate(vocabulary):
        vector[i] = idf[term] * counts[term]
    return vector

document_vectors = [vectorize(s, vocabulary, idf_obj) for s in documents]
np.array(vocabulary)[np.where(np.array(document_vectors[1]) > 0)], np.array(document_vectors[1])[np.where(np.array(document_vectors[1]) > 0)]
# Out:
# Counter({'so': 1, 'the': 1, 'robot': 1, 'spare': 1, 'human': 1, 'http': 1})
# Counter({'b': 1, 'waltmossberg': 1, 'mim': 1, 'exactli': 1, 'tesla': 1, 'is': 1, 'absurdli': 1, 'overvalu': 1, 'if': 1, 'base': 1, 'on': 1, 'the': 1, 'past': 1, 'but': 1, 'that': 1, 'http': 1})
# Counter({'b': 1, 'waltmossberg': 1, 'mim': 1, 'Et': 1, 'tu': 1, 'walt': 1})
# Counter({'weather': 1, 'in': 1, 'shortvil': 1})
# Counter({'b': 1, 'daveleebbc': 1, 'verg': 1, 'coal': 1, 'is': 1, 'die': 1, 'due': 1, 'to': 1, 'nat': 1, 'ga': 1, 'frack': 1, 'It': 1, 'basic': 1, 'dead': 1})
# Counter({'helicopt': 2, 'b': 1, 'lexxxzi': 1, 'It': 1, 'just': 1, 'a': 1, 'in': 1, 'cloth': 1})
# Counter({'b': 1, 'verg': 1, 'It': 1, 'wo': 1, 'matter': 1})
# Counter({'b': 1, 'supercoolcub': 1, 'pretti': 1, 'good': 1})
# Counter({'you': 2, 'b': 1, 'whi': 1, 'did': 1, 'we': 1, 'wast': 1, 'so': 1, 'much': 1, 'time': 1, 'develop': 1, 'silli': 1, 'rocket': 1, 'damn': 1, 'alien': 1, 'So': 1, 'obtus': 1, 'have': 1, 'all': 1, 'thi': 1, 'crazi': 1, 'tech': 1, 'but': 1, 'ca': 1, 'speak': 1, 'english': 1})
# Counter({'breakthrough': 1, 'turn': 1, 'out': 1, 'chemtrail': 1, 'are': 1, 'actual': 1, 'a': 1, 'messag': 1, 'from': 1, 'alien': 1, 'describ': 1, 'the': 1, 'secret': 1, 'of': 1, 'teleport': 1})
# Counter({'b': 1, 'RT': 1, 'openai': 1, 'We': 1, 'creat': 1, 'the': 1, 'world': 1, 'first': 1, 'AI': 1, 'train': 1, 'entir': 1, 'in': 1, 'simul': 1, 'and': 1, 'deploy': 1, 'on': 1, 'a': 1, 'physic': 1, 'robot': 1, 'http': 1})
# Counter({'profbriancox': 1, 'thi': 1, 'is': 1, 'extrem': 1, 'import': 1, 'from': 1, 'elonmusk': 1, 'and': 1, 'spacex': 1, 'reusabl': 1, 'rocket': 1, 'bring': 1, 'us': 1, 'much': 1, 'closer': 1, 'to': 1, 'becom': 1, 'a': 1})
# Counter({'b': 1, 'adamsbj': 1, 'def': 1, 'with': 1, 'although': 1, 'the': 1, 'rocket': 1, 'start': 1, 'go': 1, 'a': 1, 'lot': 1, 'faster': 1, 'after': 1, 'that': 1})
# Counter({'b': 1, 'badastronom': 1, 'We': 1, 'can': 1, 'def': 1, 'bring': 1, 'it': 1, 'back': 1, 'like': 1, 'dragon': 1, 'just': 1, 'a': 1, 'question': 1, 'of': 1, 'how': 1, 'much': 1, 'weight': 1, 'we': 1, 'need': 1, 'to': 1, 'add': 1})
# Counter({'b': 1, 'teslamotor': 1, 'work': 1, 'on': 1, 'it': 1})
# Counter({'b': 1, 'jasonlamb': 1, 'look': 1, 'like': 1, 'it': 1, 'could': 1, 'do': 1, 'more': 1, 'with': 1, 'some': 1, 'structur': 1, 'upgrad': 1, 'to': 1, 'handl': 1, 'higher': 1, 'load': 1, 'but': 1, 'that': 1, 'in': 1, 'fulli': 1, 'expend': 1, 'mode': 1})
# Counter({'b': 1, 'cheron': 1, 'A': 1, 'lot': 1})
# Counter({'of': 2, 'b': 1, 'cardoso': 1, 'silliest': 1, 'thing': 1, 'we': 1, 'can': 1, 'imagin': 1, 'secret': 1, 'payload': 1, 'dragon': 1, 'flight': 1, 'wa': 1, 'a': 1, 'giant': 1, 'wheel': 1, 'chees': 1, 'inspir': 1, 'http': 1})
# Counter({'b': 1, 'redletterdav': 1, 'good': 1, 'point': 1, 'odd': 1, 'go': 1, 'from': 1, 'to': 1, 'gt': 1})
# Counter({'heavi': 1, 'test': 1, 'flight': 1, 'current': 1, 'schedul': 1, 'for': 1, 'late': 1, 'summer': 1})
# Counter({'tri': 1, 'to': 1, 'bring': 1, 'upper': 1, 'stage': 1, 'back': 1, 'on': 1, 'falcon': 1, 'heavi': 1, 'demo': 1, 'flight': 1, 'for': 1, 'full': 1, 'reusabl': 1, 'odd': 1, 'of': 1, 'success': 1, 'low': 1, 'but': 1, 'mayb': 1, 'worth': 1, 'a': 1, 'shot': 1})
# Counter({'browser': 2, 'b': 1, 'oxfordteddi': 1, 'is': 1, 'alreadi': 1, 'a': 1, 'littl': 1, 'better': 1, 'kernel': 1, 'and': 1, 'updat': 1, 'in': 1, 'prob': 1, 'week': 1, 'or': 1, 'so': 1, 'lot': 1, 'of': 1, 'http': 1})
# Counter({'http': 2, 'spacex': 1, 'more': 1, 'photo': 1, 'from': 1, 'falcon': 1, 'launch': 1, 'and': 1, 'first': 1, 'stage': 1, 'land': 1})
# Counter({'b': 1, 'badastronom': 1, 'spacex': 1, 'thank': 1, 'phil': 1})
# Counter({'proud': 1, 'of': 1, 'the': 1, 'spacex': 1, 'team': 1, 'for': 1, 'achiev': 1, 'thi': 1, 'mileston': 1, 'in': 1, 'space': 1, 'next': 1, 'goal': 1, 'is': 1, 'reflight': 1, 'within': 1, 'hour': 1})
# Counter({'first': 2, 'spacex': 1, 'falcon': 1, 'stage': 1, 'ha': 1, 'land': 1, 'on': 1, 'Of': 1, 'cours': 1, 'I': 1, 'still': 1, 'love': 1, 'you': 1, 'reflight': 1, 'of': 1, 'an': 1, 'orbit': 1, 'class': 1, 'rocket': 1})
# Counter({'http': 2, 'spacex': 1, 'minut': 1, 'until': 1, 'launch': 1, 'window': 1, 'for': 1, 'open': 1, 'all': 1, 'system': 1, 'and': 1, 'weather': 1, 'are': 1, 'go': 1, 'watch': 1, 'here': 1})
# Counter({'spacex': 1, 'falcon': 1, 'and': 1, 'vertic': 1, 'on': 1, 'kennedi': 1, 'space': 1, 'histor': 1, 'pad': 1, 'launch': 1, 'window': 1, 'open': 1, 'at': 1, 'edt': 1, 'utc': 1, 'http': 1})
# Counter({'today': 1, 'on': 1, 'tesla': 1, 'sketch': 1, 'pad': 1, 'http': 1})
# Counter({'the': 2, 'you': 1, 'just': 1, 'download': 1, 'tap': 1, 'T': 1, 'on': 1, 'center': 1, 'screen': 1, 'three': 1, 'time': 1})
# Counter({'center': 2, 'screen': 2, 'b': 1, 'drmanejwala': 1, 'arctechinc': 1, 'On': 1, 'also': 1, 'show': 1, 'speed': 1, 'as': 1, 'an': 1, 'overlay': 1, 'that': 1, 'chang': 1, 'opac': 1, 'accord': 1, 'to': 1, 'relev': 1})
# Counter({'b': 1, 'danahul': 1, 'veri': 1, 'few': 1, 'We': 1, 'have': 1, 'yet': 1, 'to': 1, 'do': 1, 'a': 1, 'china': 1, 'or': 1, 'europ': 1, 'launch': 1, 'of': 1, 'model': 1})
# Counter({'to': 2, 'b': 1, 'busi': 1, 'glad': 1, 'have': 1, 'tencent': 1, 'as': 1, 'an': 1, 'investor': 1, 'and': 1, 'advisor': 1, 'tesla': 1})
# Counter({'b': 1, 'No': 1})
# Counter({'b': 1, 'you': 1, 'wo': 1, 'care': 1})
# Counter({'b': 1, 'nakatomitim': 1, 'what': 1, 'gave': 1, 'me': 1, 'away': 1})
# Counter({'b': 1, 'No': 1})
# Counter({'the': 3, 'is': 1, 'latest': 1, 'spacex': 1, 'travel': 1, 'ad': 1, 'for': 1, 'flight': 1, 'around': 1, 'moon': 1, 'amp': 1, 'into': 1, 'deep': 1, 'space': 1, 'mayb': 1, 'need': 1, 'a': 1, 'few': 1, 'edit': 1, 'http': 1})
# Counter({'to': 2, 'neuralink': 1, 'piec': 1, 'come': 1, 'out': 1, 'on': 1, 'waitbutwhi': 1, 'in': 1, 'about': 1, 'a': 1, 'week': 1, 'difficult': 1, 'dedic': 1, 'the': 1, 'time': 1, 'but': 1, 'existenti': 1, 'risk': 1, 'is': 1, 'too': 1, 'high': 1, 'not': 1})
# Counter({'b': 1, 'RT': 1, 'openai': 1, 'new': 1, 'research': 1, 'releas': 1, 'overcom': 1, 'mani': 1, 'of': 1, 'reinforc': 1, 'learn': 1, 'limit': 1, 'with': 1, 'evolut': 1, 'strategi': 1, 'http': 1})
# Counter({'would': 2, 'b': 1, 'erikhaaland': 1, 'We': 1, 'can': 1, 'not': 1, 'make': 1, 'all': 1, 'countri': 1, 'version': 1, 'simultan': 1, 'or': 1, 'the': 1, 'product': 1, 'start': 1, 'be': 1, 'a': 1, 'disast': 1, 'you': 1, 'get': 1, 'first': 1, 'in': 1, 'norway': 1})
# Counter({'b': 1, 'ye': 1})
# Counter({'b': 1, 'ye': 1})
# Counter({'b': 1, 'nickbaum': 1, 'I': 1, 'believ': 1, 'so': 1})
# Counter({'b': 1, 'nddugan': 1, 'yup': 1})
# Counter({'b': 1, 'Oh': 1, 'so': 1, 'littl': 1, 'faith': 1})
# Counter({'b': 1, 'kryniog': 1, 'the': 1, 'shorter': 1, 'wheelbas': 1, 'onli': 1, 'allow': 1, 'for': 1, 'a': 1, 'kwh': 1, 'pack': 1, 'in': 1, 'model': 1, 'at': 1, 'current': 1, 'energi': 1, 'densiti': 1})
# Counter({'it': 2, 'I': 2, 'pokervixen': 1, 'elonmusk': 1, 'so': 1, 'unbeliev': 1, 'happi': 1, 'with': 1, 'my': 1, 'model': 1, 'when': 1, 'peopl': 1, 'ask': 1, 'if': 1, 'l': 1, 'like': 1, 'respond': 1, 'No': 1, 'love': 1, 'amaz': 1})
# Counter({'elonmusk': 1, 'our': 1, 'hit': 1, 'the': 1, 'guardrail': 1, 'at': 1, 'well': 1, 'over': 1, 'tessi': 1, 'absorb': 1, 'impact': 1, 'wife': 1, 'and': 1, 'babi': 1, 'are': 1, 'best': 1, 'car': 1, 'ever': 1, 'amp': 1, 'member': 1})
# Counter({'b': 1, 'toddgerken': 1, 'yeah': 1})
# Counter({'b': 1, 'holsmichael': 1, 'start': 1, 'take': 1, 'order': 1, 'in': 1, 'april': 1})
# Counter({'a': 2, 'b': 1, 'yeah': 1, 'probabl': 1, 'year': 1, 'from': 1, 'now': 1, 'S': 1, 'will': 1, 'still': 1, 'win': 1, 'on': 1, 'acceler': 1, 'though': 1, 'due': 1, 'to': 1, 'have': 1, 'more': 1, 'space': 1, 'for': 1, 'larger': 1, 'batteri': 1})
# Counter({'model': 2, 'for': 2, 'morrisonbrett': 1, 'elonmusk': 1, 'first': 1, 'batch': 1, 'S': 1, 'me': 1, 'grey': 1, 'signatur': 1, 'X': 1, 'wife': 1, 'tripl': 1, 'white': 1, 'best': 1, 'vehicl': 1, 'in': 1, 'the': 1})
# Counter({'b': 1, 'akawreck': 1, 'ckalapala': 1, 'onli': 1, 'model': 1, 'S': 1, 'will': 1, 'have': 1, 'the': 1, 'seven': 1, 'seater': 1, 'option': 1, 'more': 1, 'cargo': 1, 'space': 1, 'plu': 1, 'higher': 1, 'rang': 1, 'http': 1})
# Counter({'and': 3, 'we': 2, 'model': 2, 'arctechinc': 1, 'elonmusk': 1, 'believ': 1, 'so': 1, 'much': 1, 'in': 1, 'tesla': 1, 'it': 1, 'goal': 1, 'have': 1, 'a': 1, 'S': 1, 'X': 1, 'love': 1, 'both': 1, 'thank': 1, 'you': 1, 'http': 1})
# Counter({'the': 2, 'is': 2, 'it': 2, 'b': 1, 'camkod': 1, 'model': 1, 'S': 1, 'produc': 1, 'today': 1, 'arguabl': 1, 'version': 1, 'let': 1, 'me': 1, 'put': 1, 'thi': 1, 'way': 1, 'car': 1, 'I': 1, 'will': 1, 'keep': 1, 'http': 1})
# Counter({'b': 1, 'RT': 1, 'elonmusk': 1, 'My': 1, 'lil': 1, 'monster': 1, 'tesla': 1, 'model': 1, 'X': 1, 'is': 1, 'the': 1, 'best': 1, 'car': 1, 'I': 1, 'ever': 1, 'use': 1, 'thank': 1, 'you': 1, 'elon': 1})
# Counter({'will': 2, 'b': 1, 'bluebowl': 1, 'If': 1, 'fate': 1, 'is': 1, 'on': 1, 'our': 1, 'side': 1, 'it': 1, 'be': 1, 'amaz': 1, 'talk': 1, 'about': 1, 'that': 1, 'in': 1, 'detail': 1, 'next': 1, 'week': 1})
# Counter({'b': 1, 'juanmlemao': 1, 'No': 1, 'problem': 1})
# Counter({'we': 2, 'as': 2, 'b': 1, 'djburg': 1, 'should': 1, 'be': 1, 'summer': 1, 'next': 1, 'year': 1, 'sorri': 1, 'realli': 1, 'wish': 1, 'could': 1, 'get': 1, 'rhd': 1, 'done': 1, 'sooner': 1, 'We': 1, 'truli': 1, 'are': 1, 'work': 1, 'fast': 1, 'can': 1})
# Counter({'b': 1, 'faultywarrior': 1, 'fredericlambert': 1, 'timshelton': 1, 'jimpengelli': 1, 'let': 1, 'me': 1, 'just': 1, 'go': 1, 'fetch': 1, 'my': 1, 'magic': 1, 'wand': 1})
# Counter({'b': 1, 'RT': 1, 'ricardotwumasi': 1, 'elonmusk': 1, 'My': 1, 'tesla': 1, 'model': 1, 'S': 1, 'is': 1, 'the': 1, 'best': 1, 'car': 1, 'I': 1, 'ever': 1, 'had': 1, 'http': 1})
# Counter({'b': 1, 'RT': 1, 'shkottt': 1, 'elonmusk': 1, 'my': 1, 'tesla': 1, 'roadster': 1, 'is': 1, 'the': 1, 'best': 1, 'car': 1, 'i': 1, 'ever': 1, 'had': 1})
# Counter({'in': 2, 'as': 2, 'b': 1, 'timshelton': 1, 'fredericlambert': 1, 'jimpengelli': 1, 'first': 1, 'line': 1, 'for': 1, 'dual': 1, 'motor': 1, 'soon': 1, 'we': 1, 'can': 1, 'make': 1, 'it': 1, 'which': 1, 'is': 1, 'probabl': 1, 'to': 1, 'month': 1})
# Counter({'b': 1, 'damn': 1, 'straight': 1, 'we': 1, 'do': 1, 'come': 1, 'with': 1, 'next': 1, 'week': 1})
# Counter({'of': 2, 'drive': 1, 'a': 1, 'releas': 1, 'candid': 1, 'version': 1, 'model': 1, 'http': 1})
# Counter({'b': 1, 'fredericlambert': 1, 'It': 1, 'still': 1, 'ha': 1, 'one': 1, 'display': 1})
# Counter({'b': 1, 'RT': 1, 'danieltadro': 1, 'bobbykansara': 1, 'elonmusk': 1, 'mrthorman': 1, 'My': 1, 'model': 1, 'S': 1, 'is': 1, 'the': 1, 'best': 1, 'car': 1, 'I': 1, 'ever': 1, 'had': 1})
# Counter({'new': 2, 'b': 1, 'voltzcoreaudio': 1, 'noth': 1, 'majorli': 1, 'that': 1, 'a': 1, 'consum': 1, 'would': 1, 'notic': 1, 'lot': 1, 'of': 1, 'tech': 1, 'in': 1, 'the': 1, 'design': 1, 'and': 1, 'product': 1, 'process': 1, 'though': 1})
# Counter({'the': 3, 'you': 2, 'b': 1, 'arctechinc': 1, 'more': 1, 'autonom': 1, 'a': 1, 'car': 1, 'is': 1, 'less': 1, 'dash': 1, 'info': 1, 'need': 1, 'how': 1, 'often': 1, 'do': 1, 'look': 1, 'at': 1, 'instrument': 1, 'http': 1})
# Counter({'the': 2, 'b': 1, 'how': 1, 'about': 1, 'video': 1, 'we': 1, 'just': 1, 'took': 1, 'of': 1, 'first': 1, 'model': 1, 'releas': 1, 'candid': 1, 'drive': 1})
# Counter({'bobbykansara': 1, 'mrthorman': 1, 'elonmusk': 1, 'My': 1, 'model': 1, 'X': 1, 'is': 1, 'the': 1, 'greatest': 1, 'thing': 1, 'I': 1, 'have': 1, 'ever': 1, 'purchas': 1, 'period': 1})
# Counter({'b': 1, 'trabru': 1, 'yup': 1, 'machin': 1, 'arriv': 1, 'next': 1, 'month': 1, 'and': 1, 'we': 1, 'start': 1, 'dig': 1, 'the': 1, 'tunnel': 1})
# Counter({'b': 1, 'oakhal': 1, 'I': 1, 'think': 1, 'so': 1})
# Counter({'b': 1, 'fredericlambert': 1, 'jimpengelli': 1, 'No': 1, 'we': 1, 'are': 1, 'minim': 1, 'configur': 1, 'complex': 1, 'to': 1, 'keep': 1, 'the': 1, 'product': 1, 'ramp': 1, 'on': 1, 'http': 1})
# Counter({'b': 1})
# Counter({'b': 1, 'jdaz': 1, 'becaus': 1, 'I': 1, 'wa': 1, 'a': 1, 'dumb': 1, 'idiot': 1, 'and': 1, 'did': 1, 'realiz': 1, 'at': 1, 'the': 1, 'time': 1, 'that': 1, 'it': 1, 'would': 1, 'caus': 1, 'confus': 1})
# Counter({'b': 1, 'timothymjr': 1, 'next': 1, 'week': 1})
# Counter({'b': 1, 'ye': 1, 'model': 1, 'S': 1, 'will': 1, 'alway': 1, 'be': 1, 'the': 1, 'fastest': 1, 'tesla': 1, 'until': 1, 'next': 1, 'gen': 1, 'roadster': 1, 'which': 1, 'is': 1, 'a': 1, 'few': 1, 'year': 1, 'away': 1})
# Counter({'b': 1, 'jimpengelli': 1, 'ye': 1, 'but': 1, 'not': 1, 'until': 1, 'next': 1, 'year': 1})
# Counter({'b': 1, 'alsaibi': 1, 'ye': 1, 'hardwar': 1, 'alreadi': 1, 'on': 1, 'all': 1, 'product': 1, 'S': 1, 'and': 1, 'X': 1, 'car': 1})
# Counter({'model': 2, 'is': 2, 'like': 2, 'bmw': 2, 'seri': 2, 'b': 1, 'sorta': 1, 'a': 1, 'or': 1, 'audi': 1, 'S': 1, 'and': 1, 'but': 1, 'much': 1, 'http': 1})
# Counter({'b': 1, 'how': 1, 'about': 1, 'now': 1})
# Counter({'b': 1, 'varunfatehpuria': 1, 'Oh': 1, 'model': 1, 'Y': 1, 'is': 1, 'come': 1, 'too': 1, 'in': 1, 'a': 1, 'few': 1, 'year': 1, 'kinda': 1, 'have': 1, 'to': 1})
# Counter({'b': 1, 'luciojr': 1, 'all': 1, 'tesla': 1, 'car': 1, 'built': 1, 'sinc': 1, 'oct': 1, 'last': 1, 'year': 1, 'will': 1, 'be': 1, 'capabl': 1, 'of': 1, 'as': 1, 'softwar': 1, 'improv': 1})
# Counter({'b': 1, 'swindeez': 1, 'definit': 1})
# Counter({'to': 2, 'it': 2, 'wa': 1, 'go': 1, 'be': 1, 'call': 1, 'model': 1, 'E': 1, 'for': 1, 'obviou': 1, 'dumb': 1, 'humor': 1, 'reason': 1, 'but': 1, 'ford': 1, 'su': 1, 'block': 1, 'so': 1, 'now': 1, 'is': 1, 'total': 1, 'differ': 1})
# Counter({'b': 1, 'timbeiko': 1, 'ye': 1})
# Counter({'more': 2, 'model': 2, 'S': 2, 'amp': 2, 'is': 1, 'just': 1, 'a': 1, 'smaller': 1, 'afford': 1, 'version': 1, 'of': 1, 'w': 1, 'less': 1, 'rang': 1, 'power': 1, 'fewer': 1, 'featur': 1, 'ha': 1, 'advanc': 1, 'technolog': 1})
# Counter({'is': 2, 'notic': 1, 'that': 1, 'mani': 1, 'peopl': 1, 'think': 1, 'model': 1, 'the': 1, 'next': 1, 'version': 1, 'of': 1, 'a': 1, 'tesla': 1, 'like': 1, 'iphon': 1, 'vs': 1, 'thi': 1, 'not': 1, 'true': 1})
# Counter({'b': 1, 'macwaltersl': 1, 'look': 1, 'forward': 1, 'to': 1, 'play': 1, 'the': 1, 'game': 1, 'with': 1, 'my': 1, 'kid': 1})
# Counter({'use': 2, 'b': 1, 'I': 1, 'to': 1, 'be': 1, 'one': 1, 'you': 1, 'welcom': 1, 'tri': 1, 'my': 1, 'best': 1, 'at': 1, 'least': 1, 'hope': 1, 'it': 1, 'a': 1, 'bit': 1})
# Counter({'I': 2, 'to': 2, 'b': 1, 'nextspaceflight': 1, 'inversedotcom': 1, 'just': 1, 'becaus': 1, 'build': 1, 'a': 1, 'spaceship': 1, 'get': 1, 'back': 1, 'my': 1, 'home': 1, 'planet': 1, 'doe': 1, 'mean': 1, 'an': 1, 'alien': 1})
# Counter({'b': 1, 'inversedotcom': 1, 'the': 1, 'number': 1, 'of': 1, 'extinct': 1, 'singl': 1, 'planet': 1, 'civil': 1, 'probabl': 1, 'exce': 1, 'live': 1, 'civ': 1, 'by': 1, 'at': 1, 'http': 1})
# Counter({'veri': 2, 'b': 1, 'phirat': 1, 'probabl': 1, 'either': 1, 'that': 1, 'simul': 1, 'great': 1, 'filter': 1, 'or': 1, 'they': 1, 'are': 1, 'subtl': 1})
# Counter({'b': 1, 'nite': 1, 'I': 1, 'hope': 1, 'that': 1, 'did': 1, 'work': 1})
# Counter({'b': 1, 'nite': 1})
# Counter({'are': 1, 'the': 1, 'gt': 1, 'alien': 1, 'http': 1})
# Counter({'b': 1, 'wouterhuij': 1, 'look': 1, 'like': 1, 'for': 1, 'releas': 1})
# Counter({'b': 1, 'except': 1, 'that': 1, 'is': 1, 'actual': 1, 'my': 1, 'hous': 1})
# Counter({'b': 1, 'karaswish': 1, 'perhap': 1, 'there': 1, 'will': 1, 'be': 1, 'some': 1, 'futur': 1, 'bill': 1, 'that': 1, 'make': 1, 'a': 1, 'differ': 1, 'for': 1, 'mar': 1, 'but': 1, 'thi': 1, 'is': 1, 'not': 1, 'it': 1})
# Counter({'b': 1, 'karaswish': 1, 'I': 1, 'am': 1, 'not': 1, 'thi': 1, 'bill': 1, 'chang': 1, 'almost': 1, 'noth': 1, 'about': 1, 'what': 1, 'nasa': 1, 'is': 1, 'do': 1, 'exist': 1, 'program': 1, 'stay': 1, 'in': 1, 'place': 1, 'http': 1})
# Counter({'you': 3, 'of': 2, 'b': 1, 'RT': 1, 'ryanrossuk': 1, 'elonmusk': 1, 'hope': 1, 'like': 1, 'my': 1, 'model': 1, 'X': 1, 'custom': 1, 'stori': 1, 'someth': 1, 'a': 1, 'hero': 1, 'mine': 1, 'never': 1, 'give': 1, 'up': 1, 'and': 1, 'thank': 1, 'http': 1})
# Counter({'spacex': 1, 'recoveri': 1, 'team': 1, 'en': 1, 'rout': 1, 'to': 1, 'dragon': 1, 'http': 1})
# Counter({'http': 2, 'b': 1, 'RT': 1, 'spacex': 1, 'more': 1, 'photo': 1, 'from': 1, 'today': 1, 'falcon': 1, 'launch': 1})
# Counter({'spacex': 1, 'success': 1, 'deploy': 1, 'of': 1, 'echostar': 1, 'xxiii': 1, 'to': 1, 'a': 1, 'geosynchron': 1, 'transfer': 1, 'orbit': 1, 'confirm': 1, 'http': 1})
# Counter({'http': 2, 'spacex': 1, 'back': 1, 'live': 1, 'for': 1, 'final': 1, 'burn': 1, 'and': 1, 'satellit': 1, 'deploy': 1})
# Counter({'http': 2, 'spacex': 1, 'liftoff': 1})
# Counter({'b': 1, 'capnjesu': 1, 'lurpatron': 1, 'mkbhd': 1, 'jakerawr': 1, 'is': 1, 'a': 1, 'great': 1, 'car': 1, 'but': 1, 'definit': 1, 'model': 1, 'S': 1})
# Counter({'b': 1, 'kyleugh': 1, 'good': 1, 'point': 1})
# Counter({'b': 1, 'priyancaford': 1, 'I': 1, 'wish': 1, 'It': 1, 'so': 1, 'annoy': 1})
# Counter({'an': 1, 'explan': 1, 'for': 1, 'daylight': 1, 'save': 1, 'that': 1, 'make': 1, 'sens': 1, 'http': 1})
# Counter({'b': 1, 'andreelijah': 1, 'Ok': 1})
# Counter({'b': 1, 'bizbuilderusa': 1, 'mcannonbrook': 1, 'It': 1, 'been': 1, 'a': 1, 'bear': 1, 'to': 1, 'get': 1, 'done': 1, 'but': 1, 'prob': 1, 'day': 1, 'or': 1, 'so': 1, 'depend': 1, 'on': 1, 'full': 1, 'speed': 1, 'autost': 1, 'test': 1, 'result': 1})
# Counter({'it': 2, 'b': 1, 'mcannonbrook': 1, 'look': 1, 'forward': 1, 'to': 1, 'I': 1, 'know': 1, 'clich': 1, 'but': 1, 'lotr': 1, 'is': 1, 'my': 1, 'favorit': 1, 'book': 1, 'ever': 1, 'want': 1, 'http': 1})
# Counter({'b': 1, 'mcannonbrook': 1, 'vgroysman': 1, 'sure': 1, 'just': 1, 'check': 1, 'out': 1, 'my': 1, 'prior': 1, 'tweet': 1, 'on': 1, 'price': 1, 'kwh': 1, 'at': 1, 'pack': 1, 'level': 1, 'http': 1})
# Counter({'with': 2, 'and': 2, 'b': 1, 'mcannonbrook': 1, 'can': 1, 'onli': 1, 'happen': 1, 'your': 1, 'support': 1, 'work': 1, 'close': 1, 'key': 1, 'govt': 1, 'util': 1, 'leader': 1, 'who': 1, 'are': 1, 'http': 1})
# Counter({'to': 2, 'of': 2, 'the': 2, 'want': 1, 'write': 1, 'a': 1, 'note': 1, 'appreci': 1, 'mani': 1, 'australian': 1, 'who': 1, 'came': 1, 'out': 1, 'in': 1, 'support': 1, 'batteri': 1, 'plan': 1, 'especi': 1, 'mcannonbrook': 1})
# Counter({'b': 1, 'I': 1, 'love': 1, 'wikipedia': 1, 'just': 1, 'get': 1, 'better': 1, 'over': 1, 'time': 1})
# Counter({'motor': 2, 'an': 2, 'b': 1, 'jmmzherrera': 1, 'answer': 1, 'is': 1, 'complex': 1, 'for': 1, 'electr': 1, 'We': 1, 'use': 1, 'AC': 1, 'induct': 1, 'fed': 1, 'by': 1, 'a': 1, 'DC': 1, 'pack': 1, 'thru': 1, 'igbt': 1, 'http': 1})
# Counter({'b': 1, 'williamwint': 1, 'high': 1, 'voltag': 1, 'DC': 1, 'is': 1, 'for': 1, 'sure': 1, 'the': 1, 'best': 1, 'way': 1, 'to': 1, 'transmit': 1, 'electr': 1, 'over': 1, 'long': 1, 'distanc': 1, 'good': 1, 'http': 1})
# Counter({'the': 2, 'right': 2, 'direct': 1, 'current': 1, 'is': 1, 'approach': 1, 'today': 1, 'even': 1, 'though': 1, 'altern': 1, 'wa': 1, 'in': 1, 'past': 1, 'solar': 1, 'power': 1, 'amp': 1, 'electron': 1, 'both': 1, 'DC': 1})
# Counter({'b': 1, 'you': 1, 'most': 1, 'welcom': 1, 'veri': 1, 'excit': 1, 'to': 1, 'discuss': 1, 'the': 1, 'futur': 1, 'of': 1, 'electr': 1, 'renew': 1, 'storag': 1, 'arguabl': 1, 'biggest': 1, 'http': 1})
# Counter({'b': 1, 'mcannonbrook': 1, 'just': 1, 'spoke': 1, 'with': 1, 'jayweatheril': 1, 'premier': 1, 'of': 1, 'south': 1, 'australia': 1, 'veri': 1, 'impress': 1, 'govt': 1, 'is': 1, 'clearli': 1, 'http': 1})
# Counter({'b': 1, 'shail': 1, 'ye': 1, 'but': 1, 'ship': 1, 'and': 1, 'instal': 1, 'labor': 1, 'vari': 1, 'by': 1, 'countri': 1, 'as': 1, 'those': 1, 'cost': 1, 'are': 1, 'beyond': 1, 'our': 1, 'control': 1})
# Counter({'for': 2, 'and': 2, 'b': 1, 'mcannonbrook': 1, 'at': 1, 'the': 1, 'pack': 1, 'level': 1, 'system': 1, 'tesla': 1, 'is': 1, 'move': 1, 'to': 1, 'fix': 1, 'open': 1, 'price': 1, 'term': 1, 'all': 1, 'product': 1})
# Counter({'b': 1, 'mcannonbrook': 1, 'tesla': 1, 'will': 1, 'get': 1, 'the': 1, 'system': 1, 'instal': 1, 'and': 1, 'work': 1, 'day': 1, 'from': 1, 'contract': 1, 'signatur': 1, 'or': 1, 'it': 1, 'is': 1, 'free': 1, 'that': 1, 'seriou': 1, 'enough': 1, 'for': 1, 'you': 1})
# Counter({'b': 1, 'zedd': 1, 'will': 1, 'send': 1, 'you': 1, 'one': 1})
# Counter({'b': 1, 'simonakitzu': 1})
# Counter({'JJ': 1})
# Counter()
# Counter({'teslamotor': 1, 'project': 1, 'loveday': 1, 'http': 1})
# Counter({'b': 1, 'thank': 1, 'you': 1, 'for': 1, 'the': 1, 'love': 1, 'letter': 1, 'that': 1, 'sound': 1, 'like': 1, 'a': 1, 'great': 1, 'idea': 1, 'We': 1, 'do': 1, 'it': 1, 'http': 1})
# Counter({'b': 1, 'spacex': 1, 'could': 1, 'not': 1, 'do': 1, 'thi': 1, 'without': 1, 'nasa': 1, 'Ca': 1, 'express': 1, 'enough': 1, 'appreci': 1, 'http': 1})
# Counter({'b': 1, 'jamesatbuzz': 1, 'thi': 1, 'is': 1, 'not': 1, 'true': 1, 'TM': 1, 'work': 1, 'for': 1, 'a': 1, 'lot': 1, 'of': 1, 'peopl': 1, 'and': 1, 'that': 1, 'great': 1, 'but': 1, 'I': 1, 'mayb': 1, 'done': 1, 'it': 1, 'or': 1, 'time': 1, 'ever': 1})
# Counter({'me': 1, 'to': 1, 'the': 1, 'moon': 1})
# Counter({'announc': 1, 'tomorrow': 1, 'at': 1, 'pst': 1})
# Counter({'b': 1, 'mactechgeniu': 1, 'of': 1, 'cours': 1})
# Counter({'b': 1, 'duediamond': 1, 'mayb': 1, 'one': 1, 'of': 1, 'those': 1, 'too': 1})
# Counter({'coaster': 1, 'are': 1, 'awesom': 1})
# Counter({'a': 2, 'b': 1, 'johnpaulbrew': 1, 'someth': 1, 'on': 1, 'tristat': 1, 'border': 1, 'might': 1, 'work': 1, 'gigafactori': 1, 'plu': 1, 'nearbi': 1, 'support': 1, 'suppli': 1, 'chain': 1, 'need': 1, 'veri': 1, 'larg': 1, 'workforc': 1})
# Counter({'b': 1, 'donbarbieri': 1, 'greencarreport': 1, 'good': 1, 'chanc': 1, 'it': 1, 'will': 1})
# Counter({'b': 1, 'davidshepardson': 1, 'BW': 1, 'att': 1, 'toysru': 1, 'exactli': 1})
# Counter({'b': 1, 'meganmurp': 1, 'chrisfail': 1, 'BW': 1, 'I': 1, 'did': 1, 'pose': 1, 'for': 1, 'it': 1, 'hope': 1, 'that': 1, 'obviou': 1, 'or': 1, 'want': 1, 'me': 1, 'on': 1, 'cover': 1, 'tunnel': 1, 'bore': 1, 'machin': 1, 'pic': 1, 'wd': 1, 'be': 1, 'way': 1, 'better': 1})
# Counter({'b': 1, 'adrianvolt': 1, 'minor': 1, 'improv': 1, 'updat': 1, 'thi': 1, 'weekend': 1, 'high': 1, 'speed': 1, 'autost': 1, 'in': 1, 'about': 1, 'two': 1, 'week': 1})
# Counter({'tesla': 1, 'model': 1, 'X': 1, 'review': 1, 'http': 1})
# Counter({'post': 1, 'a': 1, 'video': 1, 'http': 1})
# Counter()
# Counter({'came': 1, 'back': 1, 'http': 1})
# Counter({'spacex': 1, 'falcon': 1, 'first': 1, 'stage': 1, 'ha': 1, 'land': 1, 'at': 1})
# Counter({'b': 1, 'mattnewbi': 1, 'no': 1})
# Counter({'on': 2, 'http': 2, 'nasa': 1, 'right': 1, 'schedul': 1, 'solar': 1, 'array': 1, 'have': 1, 'been': 1, 'deploy': 1, 'spacex': 1, 'dragon': 1, 'cargo': 1, 'spacecraft': 1, 'watch': 1})
# Counter({'b': 1, 'system': 1, 'wa': 1, 'green': 1, 'for': 1, 'launch': 1, 'I': 1, 'call': 1, 'it': 1, 'off': 1})
# Counter({'b': 1, 'spacecom': 1, 'they': 1, 'are': 1, 'often': 1, 'right': 1, 'but': 1, 'in': 1, 'thi': 1, 'case': 1, 'we': 1, 'have': 1, 'alreadi': 1, 'retir': 1, 'so': 1, 'much': 1, 'R': 1, 'amp': 1, 'D': 1, 'risk': 1, 'on': 1, 'dragon': 1, 'that': 1, 'I': 1, 'feel': 1, 'veri': 1, 'confid': 1, 'of': 1})
# Counter({'b': 1, 'use': 1, 'high': 1, 'pressur': 1, 'bleed': 1, 'off': 1, 'the': 1, 'fuel': 1, 'side': 1, 'kerosen': 1, 'turbopump': 1, 'so': 1, 'no': 1, 'dedic': 1, 'pump': 1, 'or': 1, 'fluid': 1, 'need': 1})
# Counter({'to': 2, 'b': 1, 'btw': 1, 'like': 1, 'be': 1, 'fine': 1, 'close': 1, 'loop': 1, 'tvc': 1, 'wd': 1, 'overcom': 1, 'error': 1, 'but': 1, 'that': 1, 'chanc': 1, 'is': 1, 'worth': 1, 'roll': 1, 'the': 1, 'dice': 1, 'better': 1, 'wait': 1, 'a': 1, 'day': 1})
# Counter({'not': 2, 'the': 2, 'b': 1, 'zybbbi': 1, 'obvious': 1, 'relat': 1, 'to': 1, 'veri': 1, 'tini': 1, 'helium': 1, 'leak': 1, 'but': 1, 'also': 1, 'out': 1, 'of': 1, 'question': 1})
# Counter({'is': 2, 'b': 1, 'If': 1, 'thi': 1, 'the': 1, 'onli': 1, 'issu': 1, 'flight': 1, 'would': 1, 'be': 1, 'fine': 1, 'but': 1, 'need': 1, 'to': 1, 'make': 1, 'sure': 1, 'that': 1, 'it': 1, 'symptomat': 1, 'of': 1, 'a': 1, 'more': 1, 'signific': 1, 'upstream': 1, 'root': 1, 'caus': 1})
# Counter({'system': 1, 'go': 1, 'except': 1, 'the': 1, 'movement': 1, 'trace': 1, 'of': 1, 'an': 1, 'upper': 1, 'stage': 1, 'engin': 1, 'steer': 1, 'hydraul': 1, 'piston': 1, 'wa': 1, 'slightli': 1, 'odd': 1, 'stand': 1, 'down': 1, 'to': 1, 'investig': 1})
# Counter({'launch': 2, 'amp': 2, 'spacex': 1, 'hour': 1, 'from': 1, 'of': 1, 'falcon': 1, 'dragon': 1, 'to': 1, 'rocket': 1, 'weather': 1, 'are': 1, 'go': 1, 'at': 1, 'ET': 1, 'utc': 1, 'http': 1})
# Counter({'the': 2, 'launch': 2, 'down': 1, 'to': 1, 'first': 1, 'spacex': 1, 'from': 1, 'apollo': 1, 'pad': 1, 'tomorrow': 1, 'morn': 1, 'http': 1})
# Counter({'ET': 2, 'b': 1, 'RT': 1, 'nasa': 1, 'hear': 1, 'from': 1, 'expert': 1, 'at': 1, 'about': 1, 'the': 1, 'statu': 1, 'of': 1, 'tomorrow': 1, 'spacex': 1, 'cargo': 1, 'launch': 1, 'to': 1, 'http': 1})
# Counter({'b': 1, 'spacex': 1, 'photo': 1, 'http': 1})
# Counter({'dragon': 1, 'demo': 1, 'mission': 1, 'go': 1, 'well': 1, 'spacex': 1, 'is': 1, 'highli': 1, 'confid': 1, 'of': 1, 'be': 1, 'abl': 1, 'to': 1, 'fli': 1, 'US': 1, 'astronaut': 1, 'in': 1, 'http': 1})
# Counter({'for': 2, 'like': 1, 'we': 1, 'are': 1, 'go': 1, 'launch': 1, 'ad': 1, 'an': 1, 'abort': 1, 'trigger': 1, 'at': 1, 'sec': 1, 'pressur': 1, 'decay': 1, 'of': 1, 'upper': 1, 'stage': 1, 'helium': 1, 'spin': 1, 'start': 1, 'system': 1})
# Counter({'a': 1, 'veri': 1, 'small': 1, 'leak': 1, 'in': 1, 'the': 1, 'upper': 1, 'stage': 1, 'If': 1, 'ok': 1, 'will': 1, 'launch': 1, 'tomorrow': 1, 'http': 1})
# Counter({'are': 2, 'b': 1, 'emenietti': 1, 'chafkin': 1, 'ye': 1, 'but': 1, 'onli': 1, 'deep': 1, 'in': 1, 'solid': 1, 'rock': 1, 'where': 1, 'the': 1, 'wall': 1, 'and': 1, 'concret': 1, 'reinforc': 1, 'arguabl': 1, 'need': 1})
# Counter({'b': 1, 'It': 1, 'much': 1, 'easier': 1, 'to': 1, 'do': 1, 'the': 1, 'cgi': 1, 'that': 1, 'way': 1})
# Counter({'the': 3, 'launch': 2, 'rocket': 1, 'amp': 1, 'land': 1, 'at': 1, 'cape': 1, 'thi': 1, 'weekend': 1, 'will': 1, 'be': 1, 'spacex': 1, 'flight': 1, 'from': 1, 'apollo': 1, 'pad': 1, 'http': 1})
# Counter({'b': 1, 'phoebecoleman': 1, 'I': 1, 'use': 1, 'that': 1, 'one': 1})
# Counter({'b': 1, 'Ok': 1, 'what': 1, 'are': 1, 'some': 1, 'good': 1, 'one': 1, 'will': 1, 'have': 1, 'to': 1, 'meter': 1, 'these': 1, 'out': 1, 'hope': 1, 'kid': 1, 'ca': 1, 'die': 1, 'from': 1, 'groan': 1, 'too': 1, 'much': 1})
# Counter({'b': 1, 'vrgtech': 1, 'floydilici': 1, 'they': 1, 'are': 1, 'do': 1, 'india': 1, 'proud': 1})
# Counter({'b': 1, 'you': 1, 'may': 1, 'come': 1, 'to': 1, 'regret': 1, 'that': 1, 'request': 1})
# Counter({'b': 1, 'littledovah': 1, 'yeah': 1, 'exactli': 1, 'So': 1, 'that': 1, 'make': 1, 'it': 1, 'cool': 1, 'right': 1})
# Counter({'b': 1, 'floydilici': 1, 'yeah': 1, 'awesom': 1, 'achiev': 1, 'by': 1, 'isro': 1, 'veri': 1, 'impress': 1})
# Counter({'there': 1, 'is': 1, 'thi': 1, 'thing': 1, 'call': 1, 'dad': 1, 'joke': 1, 'and': 1, 'I': 1, 'make': 1, 'them': 1})
# Counter({'I': 2, 'b': 1, 'ludwigmorelo': 1, 'you': 1, 'right': 1, 'ca': 1, 'hide': 1, 'ani': 1, 'more': 1, 'am': 1, 'ironi': 1, 'man': 1})
# Counter({'I': 2, 'b': 1, 'samcornwel': 1, 'they': 1, 'were': 1, 'earlier': 1, 'draft': 1, 'that': 1, 'accident': 1, 'publish': 1, 'said': 1, 'the': 1, 'same': 1, 'thing': 1, 'a': 1, 'week': 1, 'alreadi': 1})
# Counter({'appreci': 1, 'tesla': 1, 'is': 1, 'provid': 1, 'all': 1, 'repair': 1, 'cost': 1, 'free': 1, 'of': 1, 'charg': 1, 'and': 1, 'expedit': 1, 'http': 1})
# Counter({'to': 4, 'car': 2, 'a': 2, 'the': 1, 'tesla': 1, 'owner': 1, 'who': 1, 'sacrif': 1, 'damag': 1, 'hi': 1, 'own': 1, 'bring': 1, 'with': 1, 'an': 1, 'unconsci': 1, 'driver': 1, 'safe': 1, 'stop': 1})
# Counter({'b': 1, 'lollieshopmom': 1, 'best': 1, 'place': 1, 'to': 1, 'watch': 1, 'is': 1, 'on': 1, 'the': 1, 'cape': 1, 'causeway': 1})
# Counter({'b': 1, 'seacitylight': 1, 'sound': 1, 'like': 1, 'the': 1, 'tesla': 1, 'powerwal': 1, 'consum': 1, 'and': 1, 'powerpack': 1, 'might': 1, 'be': 1, 'use': 1})
# Counter({'rocket': 1, 'now': 1, 'vertic': 1, 'at': 1, 'cape': 1, 'canaver': 1, 'on': 1, 'launch': 1, 'complex': 1, 'thi': 1, 'is': 1, 'the': 1, 'same': 1, 'http': 1})
# Counter({'b': 1, 'accohen': 1, 'megangeuss': 1, 'arstechnica': 1, 'exactli': 1, 'what': 1, 'thi': 1, 'person': 1, 'said': 1, 'is': 1, 'untru': 1})
# Counter({'as': 2, 'b': 1, 'rusulalrubail': 1, 'markruffalo': 1, 'guardian': 1, 'pleas': 1, 'check': 1, 'your': 1, 'fact': 1, 'tesla': 1, 'and': 1, 'spacex': 1, 'join': 1, 'soon': 1, 'we': 1, 'receiv': 1, 'the': 1, 'file': 1, 'which': 1, 'wa': 1, 'monday': 1})
# Counter({'you': 2, 'teslamotor': 1, 'supercharg': 1, 'avail': 1, 'is': 1, 'now': 1, 'display': 1, 'on': 1, 'your': 1, 'tesla': 1, 'touchscreen': 1, 'so': 1, 'can': 1, 'see': 1, 'how': 1, 'mani': 1, 'stall': 1, 'are': 1, 'open': 1, 'befor': 1})
# Counter({'b': 1, 'dknise': 1, 'of': 1, 'cours': 1, 'it': 1, 'will': 1})
# Counter({'b': 1, 'sundalj': 1, 'should': 1, 'all': 1, 'be': 1, 'upload': 1, 'by': 1, 'next': 1, 'month': 1})
# Counter({'b': 1, 'motor': 1, 'trend': 1, 'could': 1, 'onli': 1, 'achiev': 1, 'sec': 1, 'when': 1, 'they': 1, 'test': 1, 'the': 1, 'porsch': 1})
# Counter({'a': 2, 'b': 1, 'voltzcoreaudio': 1, 'I': 1, 'do': 1, 'know': 1, 'what': 1, 'make': 1, 'you': 1, 'think': 1, 'that': 1, 'rocket': 1, 'It': 1, 'complet': 1, 'cover': 1, 'in': 1, 'tarpaulin': 1})
# Counter({'b': 1, 'RT': 1, 'spacex': 1, 'target': 1, 'for': 1, 'dragon': 1, 'next': 1, 'resuppli': 1, 'mission': 1, 'to': 1, 'the': 1, 'our': 1, 'launch': 1, 'from': 1, 'at': 1, 'nasa': 1, 'kennedi': 1})
# Counter({'schultz': 1, 'and': 1, 'jim': 1, 'baker': 1, 'articl': 1, 'in': 1, 'wsj': 1, 'regard': 1, 'a': 1, 'carbon': 1, 'tax': 1, 'http': 1})
# Counter({'b': 1, 'batlag': 1, 'ye': 1})
# Counter({'b': 1, 'hope': 1, 'for': 1, 'summer': 1, 'thi': 1, 'year': 1})
# Counter({'b': 1, 'mdcdave': 1, 'ye': 1, 'altitud': 1, 'improv': 1, 'perform': 1, 'for': 1, 'electr': 1, 'opposit': 1, 'of': 1, 'combust': 1, 'car': 1})
# Counter({'b': 1, 'veidit': 1, 'No': 1, 'will': 1, 'be': 1, 'lower': 1, 'wheelbas': 1, 'ca': 1, 'fit': 1})
# Counter({'b': 1, 'also': 1, 'tesla': 1, 'servic': 1, 'can': 1, 'remov': 1, 'front': 1, 'trunk': 1, 'liner': 1, 'if': 1, 'you': 1, 'do': 1, 'use': 1, 'it': 1, 'and': 1, 'improv': 1, 'perform': 1, 'further': 1})
# Counter({'abov': 2, 'b': 1, 'veidit': 1, 'No': 1, 'plan': 1, 'to': 1, 'take': 1, 'X': 1, 'S': 1, 'or': 1, 'kwh': 1, 'semi': 1, 'necessarili': 1, 'and': 1, 'pickup': 1, 'truck': 1, 'mayb': 1, 'will': 1, 'go': 1})
# Counter({'b': 1, 'take': 1, 'out': 1, 'the': 1, 'floor': 1, 'mat': 1, 'and': 1, 'it': 1, 'MT': 1, 'said': 1, 'everyth': 1, 'had': 1, 'to': 1, 'be': 1, 'standard': 1, 'product': 1})
# Counter({'b': 1, 'ye': 1})
# Counter({'tesla': 1, 'model': 1, 'S': 1, 'set': 1, 'motor': 1, 'trend': 1, 'world': 1, 'record': 1, 'to': 1, 'mph': 1, 'in': 1, 'sec': 1, 'http': 1})
# Counter({'of': 2, 'http': 2, 'verg': 1, 'million': 1, 'tesla': 1, 'batteri': 1, 'cell': 1, 'are': 1, 'power': 1, 'thousand': 1, 'LA': 1, 'home': 1})
# Counter({'off': 1, 'now': 1, 'that': 1, 'wa': 1, 'more': 1, 'than': 1, 'enough': 1, 'twitter': 1, 'troubl': 1, 'for': 1, 'one': 1, 'morn': 1})
# Counter({'http': 2, 'stevecas': 1, 'I': 1, 'agre': 1})
# Counter({'b': 1, 'mactechgeniu': 1, 'No': 1, 'rare': 1, 'earth': 1, 'metal': 1, 'in': 1, 'batteri': 1})
# Counter({'b': 1, 'camdtor': 1, 'trylk': 1, 'almost': 1, 'readi': 1})
# Counter({'updat': 2, 'b': 1, 'mactechgeniu': 1, 'app': 1, 'is': 1, 'about': 1, 'two': 1, 'week': 1, 'out': 1, 'linux': 1, 'kernel': 1, 'and': 1, 'browser': 1, 'probabl': 1, 'a': 1, 'month': 1, 'or': 1, 'so': 1, 'autopilot': 1, 'ha': 1, 'prioriti': 1})
# Counter({'b': 1, 'fredericlambert': 1, 'ye': 1, 'but': 1, 'model': 1, 'is': 1, 'the': 1, 'overwhelm': 1, 'prioriti': 1})
# Counter({'b': 1, 'I': 1, 'will': 1, 'post': 1, 'an': 1, 'articl': 1, 'he': 1, 'wrote': 1, 'half': 1, 'a': 1, 'centuri': 1, 'ago': 1, 'about': 1, 'fli': 1, 'through': 1, 'africa': 1, 'and': 1, 'asia': 1, 'in': 1, 'hi': 1, 'plane': 1, 'one': 1, 'of': 1, 'my': 1, 'favorit': 1, 'thing': 1})
# Counter({'b': 1, 'christesla': 1, 'fredericlambert': 1, 'almost': 1, 'there': 1, 'We': 1, 'are': 1, 'just': 1, 'be': 1, 'veri': 1, 'care': 1, 'with': 1, 'the': 1, 'rollout': 1})
# Counter({'of': 2, 'extrem': 2, 'b': 1, 'trylk': 1, 'A': 1, 'lot': 1, 'terribl': 1, 'thing': 1, 'could': 1, 'happen': 1, 'in': 1, 'four': 1, 'year': 1, 'Do': 1, 'you': 1, 'realli': 1, 'want': 1, 'anoth': 1, 'war': 1, 'that': 1, 'where': 1, 'lead': 1})
# Counter({'is': 2, 'in': 2, 'b': 1, 'fredericlambert': 1, 'yeah': 1, 'it': 1, 'hard': 1, 'to': 1, 'convey': 1, 'complex': 1, 'idea': 1, 'char': 1, 'and': 1, 'tone': 1, 'lost': 1, 'text': 1})
# Counter({'as': 2, 'the': 2, 'b': 1, 'cycletrad': 1, 'peopl': 1, 'should': 1, 'push': 1, 'to': 1, 'have': 1, 'mani': 1, 'moder': 1, 'advis': 1, 'presid': 1, 'possibl': 1, 'blind': 1, 'hate': 1, 'is': 1, 'never': 1, 'right': 1, 'answer': 1})
# Counter({'b': 1, 'fredericlambert': 1, 'roll': 1, 'out': 1, 'a': 1, 'new': 1, 'updat': 1, 'today': 1})
# Counter({'b': 1, 'reciph': 1, 'We': 1, 'should': 1, 'tri': 1, 'our': 1, 'best': 1})
# Counter({'b': 1, 'iamdevelop': 1, 'realli': 1, 'Ok': 1, 'I': 1, 'will': 1, 'work': 1, 'harder': 1, 'on': 1, 'think': 1, 'first': 1, 'and': 1, 'tweet': 1, 'second': 1, 'sorri': 1, 'for': 1, 'anyth': 1, 'thoughtless': 1})
# Counter({'b': 1, 'martinengwicht': 1, 'fredericlambert': 1, 'I': 1, 'just': 1, 'had': 1, 'three': 1, 'coffe': 1})
# Counter({'b': 1, 'thelogicbox': 1, 'ianrosswin': 1, 'mar': 1, 'is': 1, 'critic': 1, 'for': 1, 'the': 1, 'surviv': 1, 'of': 1, 'human': 1, 'and': 1, 'life': 1, 'on': 1, 'earth': 1, 'as': 1, 'we': 1, 'know': 1, 'it': 1})
# Counter({'b': 1, 'seanbroswag': 1, 'fredericlambert': 1, 'numer': 1})
# Counter({'b': 1, 'gravimetr': 1, 'energi': 1, 'densiti': 1, 'of': 1, 'batteri': 1, 'and': 1, 'achiev': 1, 'a': 1, 'high': 1, 'cell': 1, 'mass': 1, 'fraction': 1})
# Counter({'I': 2, 'My': 2, 'wa': 2, 'born': 2, 'in': 2, 'b': 1, 'love': 1, 'canada': 1, 'half': 1, 'canadian': 1, 'mom': 1, 'regina': 1, 'grandfath': 1, 'her': 1, 'dad': 1, 'american': 1, 'minnesota': 1})
# Counter({'to': 2, 'b': 1, 'fredericlambert': 1, 'Me': 1, 'too': 1, 'I': 1, 'hope': 1, 'get': 1, 'back': 1, 'regularli': 1, 'schedul': 1, 'program': 1, 'soon': 1})
# Counter({'I': 2, 'b': 1, 'brendangag': 1, 'agre': 1, 'great': 1, 'countri': 1, 'look': 1, 'forward': 1, 'to': 1, 'take': 1, 'my': 1, 'kid': 1, 'for': 1, 'a': 1, 'visit': 1, 'heard': 1, 'it': 1, 'is': 1, 'incred': 1, 'beauti': 1})
# Counter({'my': 2, 'b': 1, 'realli': 1, 'I': 1, 'alreadi': 1, 'have': 1, 'both': 1, 'feet': 1, 'in': 1, 'mouth': 1, 'and': 1, 'am': 1, 'levit': 1, 'on': 1, 'own': 1, 'idioci': 1})
# Counter({'b': 1, 'daringkid': 1, 'true': 1, 'Me': 1, 'be': 1, 'one': 1, 'of': 1, 'them': 1})
# Counter({'b': 1, 'marcelsalath': 1, 'not': 1, 'perfect': 1, 'amp': 1, 'cd': 1, 'be': 1, 'better': 1, 'but': 1, 'out': 1, 'of': 1, 'countri': 1, 'with': 1, 'onli': 1, 'a': 1, 'diff': 1, 'to': 1, 'place': 1, 'mean': 1, 'essenti': 1, 'on': 1, 'par': 1})
# Counter({'b': 1, 'andresantoniop': 1, 'fair': 1, 'point': 1, 'sorri': 1})
# Counter({'be': 2, 'advis': 2, 'should': 1, 'push': 1, 'for': 1, 'more': 1, 'moder': 1, 'to': 1, 'presid': 1, 'not': 1, 'fewer': 1, 'how': 1, 'could': 1, 'have': 1, 'onli': 1, 'extremist': 1, 'him': 1, 'possibl': 1, 'good': 1})
# Counter({'b': 1, 'realphillippoon': 1, 'need': 1, 'a': 1, 'major': 1, 'overhaul': 1})
# Counter({'b': 1, 'fifthrocket': 1, 'exactli': 1})
# Counter({'norway': 2, 'b': 1, 'aanstadgard': 1, 'is': 1, 'great': 1, 'on': 1, 'all': 1, 'level': 1, 'love': 1})
# Counter({'b': 1, 'bullflag': 1, 'yeah': 1, 'and': 1, 'twitter': 1, 'is': 1, 'a': 1, 'hater': 1, 'hellscap': 1})
# Counter({'b': 1, 'good': 1, 'grief': 1, 'not': 1, 'work': 1, 'for': 1, 'trump': 1, 'tri': 1, 'to': 1, 'provid': 1, 'advic': 1, 'that': 1, 'help': 1, 'take': 1, 'thing': 1, 'in': 1, 'a': 1, 'more': 1, 'posit': 1, 'direct': 1})
# Counter({'b': 1, 'bittermerci': 1, 'actual': 1, 'I': 1, 'think': 1, 'it': 1, 'kinda': 1, 'cool': 1})
# Counter({'that': 2, 'a': 2, 'b': 1, 'erichaegl': 1, 'ilexomat': 1, 'Is': 1, 'basic': 1, 'like': 1, 'have': 1, 'juri': 1, 'of': 1, 'peer': 1, 'is': 1, 'default': 1, 'option': 1, 'in': 1, 'the': 1, 'US': 1})
# Counter({'system': 2, 'b': 1, 'vladsavov': 1, 'those': 1, 'countri': 1, 'have': 1, 'strong': 1, 'justic': 1, 'but': 1, 'I': 1, 'put': 1, 'them': 1, 'roughli': 1, 'on': 1, 'par': 1, 'with': 1, 'US': 1, 'that': 1, 'rate': 1, 'conflat': 1, 'mani': 1, 'factor': 1})
# Counter({'did': 2, 'b': 1, 'fifthrocket': 1, 'you': 1, 'read': 1, 'my': 1, 'tweet': 1, 'I': 1, 'attack': 1, 'it': 1, 'hard': 1, 'not': 1, 'defend': 1})
# Counter({'is': 3, 'you': 2, 'what': 2, 'b': 1, 'kenemon': 1, 'right': 1, 'polit': 1, 'a': 1, 'situat': 1, 'somebodi': 1, 'go': 1, 'to': 1, 'hate': 1, 'say': 1, 'no': 1, 'matter': 1, 'that': 1})
# Counter({'are': 3, 'with': 2, 'b': 1, 'martinengwicht': 1, 'also': 1, 'good': 1, 'there': 1, 'sever': 1, 'that': 1, 'on': 1, 'par': 1, 'US': 1, 'just': 1, 'do': 1, 'think': 1, 'ani': 1, 'better': 1, 'peopl': 1, 'confus': 1, 'law': 1, 'court': 1})
# Counter({'b': 1, 'paulvankeep': 1, 'mostli': 1, 'law': 1})
# Counter({'b': 1, 'zgiarrizzo': 1, 'exactli': 1})
# Counter({'law': 3, 'the': 2, 'b': 1, 'thelaadam': 1, 'need': 1, 'to': 1, 'chang': 1, 'judg': 1, 'are': 1, 'respons': 1, 'for': 1, 'evalu': 1, 'whether': 1, 'an': 1, 'action': 1, 'break': 1, 'not': 1, 'make': 1})
# Counter({'the': 2, 'b': 1, 'humplik': 1, 'remedi': 1, 'for': 1, 'that': 1, 'is': 1, 'chang': 1, 'law': 1})
# Counter({'b': 1, 'Ok': 1, 'but': 1, 'what': 1, 'up': 1, 'the': 1, 'wig': 1})
# Counter({'are': 2, 'b': 1, 'ilexomat': 1, 'there': 1, 'mani': 1, 'good': 1, 'legal': 1, 'system': 1, 'on': 1, 'par': 1, 'with': 1, 'US': 1, 'just': 1, 'do': 1, 'know': 1, 'ani': 1, 'that': 1, 'better': 1})
# Counter({'b': 1, 'biesseman': 1, 'true': 1})
# Counter({'of': 2, 'the': 2, 'b': 1, 'mani': 1, 'in': 1, 'america': 1, 'do': 1, 'realiz': 1, 'how': 1, 'proud': 1, 'they': 1, 'should': 1, 'be': 1, 'legal': 1, 'system': 1, 'not': 1, 'perfect': 1, 'but': 1, 'nowher': 1, 'is': 1, 'caus': 1, 'justic': 1, 'better': 1, 'serv': 1})
# Counter({'to': 2, 'in': 2, 'you': 2, 'teslamotor': 1, 'honor': 1, 'receiv': 1, 'best': 1, 'car': 1, 'award': 1, 'for': 1, 'the': 1, 'third': 1, 'year': 1, 'a': 1, 'row': 1, 'germani': 1, 'thank': 1, 'all': 1, 'of': 1, 'who': 1, 'vote': 1})
# Counter({'down': 1, 'the': 1, 'street': 1, 'and': 1, 'saw': 1, 'thi': 1, 'http': 1})
# Counter({'b': 1, 'chrisjcav': 1, 'mayb': 1, 'my': 1, 'favorit': 1, 'mug': 1, 'ever': 1})
# Counter({'b': 1, 'nintendomaniac': 1, 'I': 1, 'wish': 1})
# Counter({'I': 2, 'do': 2, 'what': 2, 'right': 2, 'b': 1, 'then': 1, 'so': 1, 'be': 1, 'it': 1, 'rather': 1, 'believ': 1, 'is': 1, 'than': 1, 'appear': 1, 'simpli': 1, 'to': 1, 'avoid': 1, 'critic': 1})
# Counter({'b': 1, 'bonnienorman': 1, 'advanderm': 1, 'wow': 1, 'cool': 1})
# Counter({'b': 1, 'that': 1, 'exactli': 1, 'what': 1, 'I': 1, 'thought': 1, 'love': 1})
# Counter({'b': 1, 'nuanc': 1, 'are': 1, 'import': 1})
# Counter({'unicorn': 1, 'and': 1, 'electr': 1, 'car': 1, 'http': 1})
# Counter({'ft': 1, 'diamet': 1, 'tunnel': 1, 'run': 1, 'mile': 1, 'under': 1, 'http': 1})
# Counter({'want': 2, 'to': 2, 'b': 1, 'eveegdmann': 1, 'realli': 1, 'do': 1, 'get': 1, 'in': 1, 'polit': 1, 'I': 1, 'just': 1, 'help': 1, 'invent': 1, 'and': 1, 'develop': 1, 'technolog': 1, 'that': 1, 'improv': 1, 'live': 1, 'feel': 1, 'so': 1, 'bizarr': 1})
# Counter({'b': 1, 'daniellebloem': 1, 'ye': 1, 'for': 1, 'now': 1, 'but': 1, 'thi': 1, 'should': 1, 'be': 1, 'address': 1, 'on': 1, 'all': 1, 'front': 1, 'judici': 1, 'legisl': 1, 'and': 1, 'execut': 1})
# Counter({'I': 2, 'do': 2, 'addit': 1, 'again': 1, 'rais': 1, 'climat': 1, 'believ': 1, 'thi': 1, 'is': 1, 'good': 1, 'so': 1, 'will': 1, 'remain': 1, 'on': 1, 'council': 1, 'amp': 1, 'keep': 1, 'at': 1, 'it': 1, 'otherwis': 1, 'would': 1, 'be': 1, 'wrong': 1})
# Counter({'the': 2, 'b': 1, 'At': 1, 'my': 1, 'request': 1, 'agenda': 1, 'for': 1, 'yesterday': 1, 'white': 1, 'hous': 1, 'meet': 1, 'went': 1, 'from': 1, 'not': 1, 'mention': 1, 'travel': 1, 'ban': 1, 'to': 1, 'have': 1, 'it': 1, 'be': 1, 'first': 1, 'and': 1, 'foremost': 1})
# Counter({'b': 1, 'petergleick': 1, 'busi': 1, 'first': 1, 'I': 1, 'heard': 1, 'of': 1, 'thi': 1, 'meet': 1, 'will': 1, 'find': 1, 'out': 1, 'whi': 1})
# Counter({'b': 1, 'officeofomar': 1, 'mayb': 1})
# Counter({'the': 2, 'hyperloop': 2, 'b': 1, 'video': 1, 'of': 1, 'mit': 1, 'entrant': 1, 'into': 1, 'spacex': 1, 'competit': 1, 'air': 1, 'ha': 1, 'been': 1, 'remov': 1, 'from': 1, 'tube': 1, 'to': 1, 'http': 1})
# Counter({'http': 1})
# Counter({'amp': 2, 'b': 1, 'ye': 1, 'green': 1, 'card': 1, 'dual': 1, 'citizen': 1, 'alreadi': 1, 'work': 1, 'spousal': 1, 'visa': 1, 'not': 1, 'yet': 1, 'but': 1, 'hope': 1, 'soon': 1, 'thi': 1, 'is': 1, 'separ': 1, 'from': 1, 'judici': 1, 'action': 1})
# Counter({'ha': 1, 'alreadi': 1, 'been': 1, 'and': 1, 'there': 1, 'will': 1, 'be': 1, 'progress': 1, 'on': 1, 'thi': 1, 'matter': 1})
# Counter({'the': 2, 'meet': 1, 'at': 1, 'white': 1, 'hous': 1, 'http': 1})
# Counter({'b': 1, 'ye': 1})
# Counter({'the': 2, 'b': 1, 'RT': 1, 'wire': 1, 'AI': 1, 'that': 1, 'beat': 1, 'world': 1, 'best': 1, 'poker': 1, 'player': 1, 'mimick': 1, 'human': 1, 'intuit': 1, 'in': 1, 'a': 1, 'way': 1, 'no': 1, 'other': 1, 'machin': 1, 'ever': 1, 'had': 1, 'http': 1})
# Counter({'b': 1, 'sarahfkessl': 1, 'qz': 1, 'headlin': 1, 'amp': 1, 'articl': 1, 'is': 1, 'mislead': 1, 'I': 1, 'said': 1, 'it': 1, 'wo': 1, 'be': 1, 'retract': 1, 'ie': 1, 'withdrawn': 1, 'by': 1, 'pre': 1, 'It': 1, 'may': 1, 'http': 1})
# Counter({'b': 1, 'reesandersen': 1, 'flixrisk': 1, 'ye': 1, 'I': 1, 'believ': 1, 'that': 1, 'is': 1, 'critic': 1, 'to': 1, 'ensur': 1, 'a': 1, 'good': 1, 'futur': 1, 'for': 1, 'human': 1})
# Counter({'AI': 2, 'research': 1, 'agre': 1, 'on': 1, 'principl': 1, 'for': 1, 'develop': 1, 'benef': 1, 'http': 1})
# Counter({'the': 3, 'b': 1, 'RT': 1, 'teslamotor': 1, 'meet': 1, 'util': 1, 'grid': 1, 'of': 1, 'futur': 1, 'tesla': 1, 'powerpack': 1, 'instal': 1, 'at': 1, 'sce': 1, 'substat': 1, 'will': 1, 'reduc': 1, 'LA': 1, 'basin': 1})
# Counter({'great': 2, 'b': 1, 'inhaleray': 1, 'I': 1, 'agre': 1, 'with': 1, 'creat': 1, 'job': 1, 'restor': 1, 'US': 1, 'strength': 1, 'as': 1, 'a': 1, 'manufactur': 1, 'of': 1, 'product': 1, 'and': 1, 'http': 1})
# Counter({'b': 1, 'mcwm': 1, 'jackclarksf': 1, 'yeah': 1, 'sorri': 1, 'about': 1, 'that': 1})
# Counter({'the': 2, 'is': 2, 'b': 1, 'jacobofamb': 1, 'ye': 1, 'order': 1, 'still': 1, 'bad': 1, 'but': 1, 'it': 1, 'alway': 1, 'import': 1, 'to': 1, 'read': 1, 'sourc': 1, 'materi': 1})
# Counter({'read': 2, 'the': 2, 'sourc': 2, 'materi': 2, 'b': 1, 'is': 1, 'better': 1, 'than': 1, 'other': 1, 'peopl': 1, 'opinion': 1, 'about': 1, 'http': 1})
# Counter({'hyperloop': 3, 'b': 1, 'RT': 1, 'congrat': 1, 'to': 1, 'warr': 1, 'team': 1, 'for': 1, 'fastest': 1, 'pod': 1, 'flew': 1, 'down': 1, 'entir': 1, 'length': 1, 'of': 1, 'track': 1, 'at': 1, 'the': 1, 'world': 1, 'first': 1})
# Counter({'hyperloop': 2, 'http': 2, 'watch': 1, 'live': 1, 'replay': 1, 'now': 1, 'of': 1, 'both': 1, 'mit': 1, 'and': 1, 'warr': 1, 'test': 1, 'flight': 1, 'at': 1, 'breakapod': 1})
# Counter({'hyperloop': 3, 'watchliv': 1, 'now': 1, 'at': 1, 'http': 1, 'as': 1, 'warr': 1, 'team': 1, 'attempt': 1, 'their': 1, 'first': 1, 'flight': 1, 'in': 1, 'the': 1, 'spacex': 1, 'test': 1})
# Counter({'b': 1, 'danahul': 1, 'strateg': 1, 'amp': 1, 'polici': 1, 'forum': 1})
# Counter({'there': 2, 'is': 2, 'possibl': 2, 'of': 2, 'b': 1, 'redletterdav': 1, 'exactli': 1, 'no': 1, 'retract': 1, 'but': 1, 'http': 1})
# Counter({'read': 1, 'immigr': 1, 'order': 1, 'lmk': 1, 'specif': 1, 'amend': 1, 'will': 1, 'seek': 1, 'advisori': 1, 'council': 1, 'consensu': 1, 'amp': 1, 'present': 1, 'to': 1, 'presid': 1, 'http': 1})
# Counter({'b': 1, 'parparv': 1, 'It': 1, 'is': 1, 'not': 1})
# Counter({'b': 1, 'mani': 1, 'peopl': 1, 'neg': 1, 'affect': 1, 'by': 1, 'thi': 1, 'polici': 1, 'are': 1, 'strong': 1, 'support': 1, 'of': 1, 'the': 1, 'US': 1, 'they': 1, 'done': 1, 'right': 1, 'not': 1, 'wrong': 1, 'amp': 1, 'do': 1, 'deserv': 1, 'to': 1, 'be': 1, 'reject': 1})
# Counter({'the': 2, 'blanket': 1, 'entri': 1, 'ban': 1, 'on': 1, 'citizen': 1, 'from': 1, 'certain': 1, 'primarili': 1, 'muslim': 1, 'countri': 1, 'is': 1, 'not': 1, 'best': 1, 'way': 1, 'to': 1, 'address': 1, 'challeng': 1})
# Counter({'lane': 2, 'b': 1, 'miguelgamino': 1, 'popsci': 1, 'thi': 1, 'is': 1, 'silli': 1, 'If': 1, 'ad': 1, 'actual': 1, 'did': 1, 'make': 1, 'it': 1, 'wors': 1, 'that': 1, 'would': 1, 'impli': 1, 'remov': 1, 'http': 1})
# Counter({'we': 1, 'start': 1, 'dig': 1, 'the': 1, 'tunnel': 1, 'tonight': 1, 'http': 1})
# Counter({'b': 1, 'RT': 1, 'techinsid': 1, 'here': 1, 'are': 1, 'all': 1, 'the': 1, 'futurist': 1, 'pod': 1, 'compet': 1, 'in': 1, 'elon': 1, 'musk': 1, 'hyperloop': 1, 'competit': 1, 'thi': 1, 'weekend': 1, 'http': 1})
# Counter({'pod': 1, 'race': 1, 'happen': 1, 'thi': 1, 'weekend': 1, 'at': 1, 'spacex': 1, 'HQ': 1, 'near': 1, 'lax': 1, 'We': 1, 'built': 1, 'a': 1, 'long': 1, 'vacuum': 1, 'tube': 1, 'on': 1, 'our': 1, 'campu': 1, 'big': 1, 'enough': 1, 'to': 1, 'fit': 1, 'peopl': 1})
# Counter({'a': 2, 'b': 1, 'yeah': 1, 'am': 1, 'hear': 1, 'thi': 1, 'from': 1, 'lot': 1, 'of': 1, 'peopl': 1, 'amp': 1, 'it': 1, 'get': 1, 'me': 1, 'down': 1, 'I': 1, 'just': 1, 'tri': 1, 'to': 1, 'make': 1, 'http': 1})
# Counter({'hyperloop': 2, 'team': 1, 'arriv': 1, 'today': 1, 'for': 1, 'test': 1, 'week': 1, 'befor': 1, 'competit': 1, 'at': 1, 'spacex': 1, 'HQ': 1, 'on': 1, 'http': 1})
# Counter({'http': 2, 'gizmodo': 1, 'A': 1, 'brief': 1, 'chat': 1, 'with': 1, 'elon': 1, 'musk': 1, 'about': 1, 'climat': 1, 'chang': 1, 'rex': 1, 'tillerson': 1, 'and': 1, 'donald': 1, 'trump': 1})
# Counter({'the': 2, 'on': 2, 'b': 1, 'theskinsfactori': 1, 'earthquak': 1, 'tend': 1, 'to': 1, 'have': 1, 'biggest': 1, 'effect': 1, 'surfac': 1, 'like': 1, 'wave': 1, 'water': 1, 'that': 1, 'whi': 1, 'LA': 1, 'http': 1})
# Counter({'from': 2, 'b': 1, 'start': 1, 'across': 1, 'my': 1, 'desk': 1, 'at': 1, 'spacex': 1, 'crenshaw': 1, 'and': 1, 'the': 1, 'freeway': 1, 'which': 1, 'is': 1, 'min': 1, 'lax': 1})
# Counter({'b': 1, 'yup': 1})
# Counter({'b': 1, 'belovedrevol': 1, 'mayb': 1, 'next': 1, 'month': 1})
# Counter({'progress': 1, 'on': 1, 'the': 1, 'tunnel': 1, 'front': 1, 'plan': 1, 'to': 1, 'start': 1, 'dig': 1, 'in': 1, 'a': 1, 'month': 1, 'or': 1, 'so': 1})
# Counter({'is': 2, 'tillerson': 1, 'support': 1, 'a': 1, 'carbon': 1, 'tax': 1, 'thi': 1, 'what': 1, 'realli': 1, 'need': 1, 'to': 1, 'move': 1, 'the': 1, 'needl': 1, 'http': 1})
# Counter({'http': 2, 'gizmodo': 1, 'whi': 1, 'it': 1, 'matter': 1, 'that': 1, 'human': 1, 'poker': 1, 'pro': 1, 'are': 1, 'get': 1, 'trounc': 1, 'by': 1, 'an': 1, 'AI': 1})
# Counter({'b': 1, 'michaelemann': 1, 'I': 1, 'just': 1, 'say': 1, 'that': 1, 'we': 1, 'should': 1, 'see': 1, 'what': 1, 'happen': 1, 'first': 1, 'the': 1, 'action': 1, 'may': 1, 'be': 1, 'surpris': 1})
# Counter({'b': 1, 'michaelemann': 1, 'No': 1, 'they': 1, 'do': 1})
# Counter({'b': 1, 'wa': 1, 'wonder': 1, 'what': 1, 'those': 1, 'were': 1})
# Counter()
# Counter({'b': 1, 'that': 1, 'may': 1, 'be': 1, 'a': 1, 'difficult': 1, 'award': 1, 'to': 1, 'declin': 1})
# Counter({'also': 1, 'said': 1, 'that': 1, 'risk': 1, 'of': 1, 'climat': 1, 'chang': 1, 'doe': 1, 'and': 1, 'he': 1, 'believ': 1, 'should': 1, 'be': 1, 'taken': 1})
# Counter({'b': 1, 'theeconomist': 1, 'on': 1, 'how': 1, 'to': 1, 'address': 1, 'threat': 1, 'of': 1, 'climat': 1, 'chang': 1, 'they': 1, 'do': 1, 'requir': 1, 'a': 1, 'global': 1, 'respons': 1})
# Counter({'b': 1, 'theeconomist': 1, 'tillerson': 1, 'at': 1, 'hi': 1, 'confirm': 1, 'hear': 1, 'I': 1, 'think': 1, 'import': 1, 'that': 1, 'the': 1, 'unit': 1, 'state': 1, 'maintain': 1, 'it': 1, 'http': 1})
# Counter({'b': 1, 'redletterdav': 1, 'Ok': 1, 'fine': 1, 'soldier': 1, 'My': 1, 'dark': 1, 'secret': 1, 'is': 1, 'out': 1})
# Counter({'the': 3, 'b': 1, 'danahul': 1, 'I': 1, 'share': 1, 'economist': 1, 'opinion': 1, 'that': 1, 'he': 1, 'should': 1, 'be': 1, 'given': 1, 'benefit': 1, 'of': 1, 'doubt': 1, 'unless': 1, 'hi': 1, 'action': 1, 'prove': 1, 'otherwis': 1})
# Counter({'is': 2, 'hi': 2, 'team': 2, 'b': 1, 'danahul': 1, 'rex': 1, 'an': 1, 'except': 1, 'compet': 1, 'execut': 1, 'understand': 1, 'geopolit': 1, 'and': 1, 'know': 1, 'how': 1, 'to': 1, 'win': 1, 'for': 1, 'now': 1, 'the': 1, 'usa': 1})
# ...
# Counter({'the': 2, 'most': 1, 'interest': 1, 'view': 1, 'of': 1, 'model': 1, 'X': 1, 'is': 1, 'realli': 1, 'with': 1, 'door': 1, 'open': 1, 'http': 1})
# Counter({'the': 1, 'superdraco': 1, 'rocket': 1, 'engin': 1, 'enabl': 1, 'launch': 1, 'escap': 1, 'and': 1, 'land': 1, 'on': 1, 'thruster': 1, 'http': 1})
# Counter({'in': 2, 'that': 2, 'while': 1, 'awesom': 1, 'it': 1, 'own': 1, 'way': 1, 'wa': 1, 'not': 1, 'actual': 1, 'the': 1, 'spacex': 1, 'theme': 1, 'song': 1, 'It': 1, 'seem': 1, 'ironi': 1, 'is': 1, 'sometim': 1, 'lost': 1, 'a': 1, 'tweet': 1})
# Counter({'ooh': 3, 'spacex': 1, 'theme': 1, 'song': 1, 'by': 1, 'total': 1, 'ghost': 1, 'is': 1, 'just': 1, 'too': 1, 'good': 1, 'http': 1})
# Counter({'ladi': 1, 'doth': 1, 'protest': 1, 'too': 1, 'littl': 1, 'http': 1})
# Counter({'on': 2, 'model': 1, 'X': 1, 'unveil': 1, 'will': 1, 'be': 1, 'webcast': 1, 'live': 1, 'http': 1, 'at': 1, 'feb': 1, 'most': 1, 'car': 1, 'are': 1, 'pretti': 1, 'blah': 1, 'thi': 1, 'is': 1, 'not': 1})
# Counter({'pictur': 1, 'of': 1, 'earth': 1, 'from': 1, 'the': 1, 'new': 1, 'nasa': 1, 'satellit': 1, 'http': 1})
# Counter({'cut': 1, 'simul': 1, 'of': 1, 'the': 1, 'spacex': 1, 'next': 1, 'gen': 1, 'rocket': 1, 'spaceship': 1, 'design': 1, 'http': 1})
# Counter({'complet': 1, 'for': 1, 'bring': 1, 'rocket': 1, 'back': 1, 'to': 1, 'launchpad': 1, 'use': 1, 'onli': 1, 'thruster': 1, 'yay': 1, 'wing': 1, 'r': 1, 'just': 1, 'dead': 1, 'weight': 1, 'in': 1, 'space': 1})
# Counter({'solar': 1, 'radiat': 1, 'storm': 1, 'in': 1, 'year': 1, 'is': 1, 'blast': 1, 'earth': 1, 'thi': 1, 'huge': 1, 'erupt': 1, 'hit': 1, 'us': 1, 'tomorrow': 1, 'http': 1})
# Counter({'some': 1, 'wood': 1, 'and': 1, 'built': 1, 'a': 1, 'littl': 1, 'treehous': 1, 'with': 1, 'my': 1, 'boy': 1, 'few': 1, 'more': 1, 'beauti': 1, 'way': 1, 'to': 1, 'spend': 1, 'an': 1, 'afternoon': 1})
# Counter({'b': 1, 'theonion': 1, 'I': 1, 'heard': 1, 'lar': 1, 'von': 1, 'trier': 1, 'option': 1, 'the': 1, 'movi': 1, 'right': 1})
# Counter({'spacex': 2, 'insid': 1, 'the': 1, 'rocket': 1, 'factori': 1, 'take': 1, 'a': 1, 'look': 1, 'with': 1, 'popmech': 1, 'http': 1})
# Counter({'they': 2, 'said': 1, 'even': 1, 'though': 1, 'caus': 1, 'me': 1, 'grief': 1, 'I': 1, 'would': 1, 'defend': 1, 'the': 1, 'right': 1, 'of': 1, 'short': 1, 'to': 1, 'exist': 1, 'are': 1, 'often': 1, 'unreason': 1, 'malign': 1})
# Counter({'b': 1, 'that': 1, 'not': 1, 'just': 1, 'paranoia': 1, 'a': 1, 'healthi': 1, 'trait': 1, 'at': 1, 'time': 1, 'tesla': 1, 'realli': 1, 'is': 1, 'under': 1, 'massiv': 1, 'attack': 1, 'by': 1, 'short': 1, 'seller': 1, 'http': 1})
# Counter({'to': 2, 'commun': 1, 'better': 1, 'in': 1, 'the': 1, 'futur': 1, 'too': 1, 'mani': 1, 'peopl': 1, 'want': 1, 'us': 1, 'fail': 1, 'and': 1, 'are': 1, 'will': 1, 'twist': 1, 'ani': 1, 'bit': 1, 'of': 1, 'news': 1, 'against': 1, 'tesla': 1})
# Counter({'down': 1, 'friday': 1, 'but': 1, 'back': 1, 'up': 1, 'today': 1, 'sorri': 1, 'for': 1, 'the': 1, 'roller': 1, 'coaster': 1})
# Counter({'need': 1, 'to': 1, 'tell': 1, 'kim': 1, 'that': 1, 'the': 1, 'showbiz': 1, 'phrase': 1, 'break': 1, 'a': 1, 'leg': 1, 'mean': 1, 'what': 1, 'he': 1, 'think': 1, 'it': 1, 'doe': 1})
# Counter({'more': 1, 'with': 1, 'feel': 1, 'north': 1, 'korea': 1, 'punish': 1, 'insincer': 1, 'mourner': 1, 'http': 1})
# Counter({'the': 2, 'mile': 2, 'b': 1, 'A': 1, 'tesla': 1, 'roadster': 1, 'just': 1, 'pass': 1, 'mark': 1, 'for': 1, 'first': 1, 'time': 1, 'and': 1, 'still': 1, 'ha': 1, 'over': 1, 'of': 1, 'rang': 1})
# Counter({'b': 1, 'what': 1, 'is': 1, 'more': 1, 'magic': 1, 'than': 1, 'cowboy': 1, 'herd': 1, 'cat': 1, 'livin': 1, 'the': 1, 'dream': 1, 'http': 1})
# Counter({'these': 1, 'day': 1, 'are': 1, 'so': 1, 'grown': 1, 'up': 1, 'RT': 1, 'wow': 1, 'audienc': 1, 'with': 1, 'school': 1, 'product': 1, 'Of': 1, 'equu': 1, 'http': 1})
# Counter({'S': 1, 'perform': 1, 'powertrain': 1, 'produc': 1, 'so': 1, 'much': 1, 'torqu': 1, 'today': 1, 'that': 1, 'we': 1, 'broke': 1, 'the': 1, 'dyno': 1, 'sec': 1, 'mph': 1, 'will': 1, 'not': 1, 'be': 1, 'a': 1, 'problem': 1})
# Counter({'to': 2, 'exec': 1, 'conf': 1, 'room': 1, 'at': 1, 'tesla': 1, 'use': 1, 'be': 1, 'call': 1, 'denali': 1, 'but': 1, 'I': 1, 'decid': 1, 'move': 1, 'a': 1, 'few': 1, 'letter': 1, 'around': 1, 'seem': 1, 'more': 1, 'apt': 1, 'http': 1})
# Counter({'S': 1, 'signatur': 1, 'seri': 1, 'sold': 1, 'out': 1, 'as': 1, 'of': 1, 'today': 1, 'http': 1})
# Counter({'the': 2, 'month': 1, 'is': 1, 'also': 1, 'when': 1, 'our': 1, 'dragon': 1, 'spaceship': 1, 'dock': 1, 'with': 1, 'space': 1, 'station': 1, 'for': 1, 'first': 1, 'time': 1, 'major': 1, 'pucker': 1, 'factor': 1})
# Counter({'is': 1, 'huge': 1, 'month': 1, 'model': 1, 'X': 1, 'world': 1, 'premier': 1, 'and': 1, 'public': 1, 'reveal': 1, 'of': 1, 'our': 1, 'LA': 1, 'design': 1, 'studio': 1, 'on': 1, 'the': 1, 'stay': 1, 'tune': 1, 'for': 1, 'more': 1, 'detail': 1})
# Counter({'b': 1, 'just': 1, 'finish': 1, 'massi': 1, 'book': 1, 'on': 1, 'catherin': 1, 'An': 1, 'amazingli': 1, 'expans': 1, 'and': 1, 'compel': 1, 'portrait': 1, 'of': 1, 'an': 1, 'incred': 1, 'woman': 1, 'highli': 1, 'recommend': 1})
# Counter({'b': 1, 'om': 1, 'respect': 1, 'disagre': 1, 'larri': 1, 'made': 1, 'awesom': 1, 'move': 1, 'last': 1, 'year': 1, 'which': 1, 'laid': 1, 'the': 1, 'foundat': 1, 'for': 1, 'to': 1, 'kick': 1, 'butt': 1, 'in': 1, 'He': 1, 'a': 1, 'stud': 1})
# Counter({'b': 1, 'what': 1, 'everyon': 1, 'realli': 1, 'think': 1, 'RT': 1, 'jonlovett': 1, 'If': 1, 'mayan': 1, 'were': 1, 'good': 1, 'at': 1, 'predict': 1, 'the': 1, 'futur': 1, 'there': 1, 'be': 1})
# Counter({'the': 2, 'a': 1, 'lighter': 1, 'note': 1, 'rhcp': 1, 'are': 1, 'awesom': 1, 'No': 1, 'better': 1, 'way': 1, 'to': 1, 'bring': 1, 'in': 1, 'new': 1, 'year': 1, 'http': 1})
# Counter({'the': 2, 'b': 1, 'I': 1, 'said': 1, 'weapon': 1, 'for': 1, 'a': 1, 'reason': 1, 'bit': 1, 'is': 1, 'mightier': 1, 'than': 1, 'bomb': 1})
# Counter({'we': 2, 'b': 1, 'If': 1, 'are': 1, 'not': 1, 'care': 1, 'will': 1, 'find': 1, 'that': 1, 'knife': 1, 'against': 1, 'liberti': 1, 'neck': 1, 'fate': 1, 'ha': 1, 'a': 1, 'great': 1, 'sens': 1, 'of': 1, 'ironi': 1, 'http': 1})
# Counter({'weapon': 2, 'enemi': 2, 'built': 1, 'power': 1, 'inform': 1, 'to': 1, 'fight': 1, 'of': 1, 'liberti': 1, 'now': 1, 'those': 1, 'are': 1, 'larg': 1, 'defeat': 1, 'but': 1, 'the': 1, 'remain': 1})
# Counter({'b': 1, 'fareedzakaria': 1, 'howev': 1, 'china': 1, 'real': 1, 'estat': 1, 'crisi': 1, 'will': 1, 'explod': 1, 'in': 1, 'a': 1, 'way': 1, 'that': 1, 'make': 1, 'our': 1, 'look': 1, 'puni': 1, 'they': 1, 'ca': 1, 'hide': 1, 'it': 1, 'for': 1, 'much': 1, 'longer': 1})
# Counter({'the': 2, 'b': 1, 'fareedzakaria': 1, 'yeah': 1, 'will': 1, 'be': 1, 'great': 1, 'for': 1, 'american': 1, 'economi': 1, 'job': 1, 'as': 1, 'we': 1, 'mostli': 1, 'dealt': 1, 'with': 1, 'overbuilt': 1, 'hous': 1, 'crisi': 1})
# Counter({'first': 1, 'predict': 1, 'of': 1, 'ha': 1, 'come': 1, 'true': 1, 'ouch': 1, 'my': 1, 'head': 1, 'hurt': 1})
# Counter({'is': 2, 'b': 1, 'world': 1, 'violenc': 1, 'be': 1, 'super': 1, 'low': 1, 'probabl': 1, 'to': 1, 'most': 1, 'peopl': 1, 'that': 1, 'becaus': 1, 'modern': 1, 'media': 1, 'a': 1, 'miseri': 1, 'microscop': 1})
# Counter({'b': 1, 'here': 1, 'a': 1, 'happi': 1, 'thought': 1, 'for': 1, 'world': 1, 'violenc': 1, 'is': 1, 'at': 1, 'an': 1, 'all': 1, 'time': 1, 'histor': 1, 'low': 1, 'excel': 1, 'piec': 1, 'by': 1, 'stephen': 1, 'pinker': 1, 'http': 1})
# Counter({'my': 1, 'tesla': 1, 'charg': 1, 'connector': 1, 'on': 1, 'a': 1, 'small': 1, 'island': 1, 'in': 1, 'the': 1, 'rain': 1, 'last': 1, 'night': 1, 'whatcouldpossiblygowrong': 1})
# Counter({'suck': 2, 'it': 2, 'that': 1, 'thi': 1, 'realli': 1, 'matter': 1, 'all': 1, 'current': 1, 'rocket': 1, 'tech': 1, 'includ': 1, 'our': 1, 'onli': 1, 'when': 1, 'becom': 1, 'fulli': 1, 'reusabl': 1, 'will': 1, 'not': 1})
# Counter({'ha': 1, 'boe': 1, 'lockhe': 1, 'europ': 1, 'arian': 1, 'and': 1, 'russia': 1, 'near': 1, 'checkmat': 1, 'in': 1, 'rocket': 1, 'technolog': 1, 'end': 1, 'game': 1, 'is': 1, 'all': 1, 'about': 1, 'china': 1})
# Counter({'unveil': 1, 'ambiti': 1, 'space': 1, 'strategi': 1, 'http': 1})
# Counter({'be': 1, 'clear': 1, 'ctg': 1, 'absolut': 1, 'did': 1, 'bang': 1, 'her': 1, 'hors': 1, 'they': 1, 'were': 1, 'just': 1, 'close': 1, 'friend': 1, 'who': 1, 'like': 1, 'to': 1, 'take': 1, 'shower': 1, 'togeth': 1, 'and': 1, 'spoon': 1, 'at': 1, 'night': 1})
# Counter({'mood': 1, 'scent': 1, 'candl': 1, 'barri': 1, 'white': 1, 'sing': 1, 'get': 1, 'enough': 1, 'of': 1, 'your': 1, 'love': 1, 'babi': 1, 'and': 1, 'the': 1, 'magic': 1, 'by': 1, 'that': 1, 'I': 1, 'mean': 1, 'happen': 1})
# Counter({'just': 2, 'u': 2, 'b': 1, 'I': 1, 'say': 1, 'that': 1, 'should': 1, 'pass': 1, 'judgment': 1, 'base': 1, 'on': 1, 'one': 1, 'night': 1, 'of': 1, 'passion': 1, 'sometim': 1, 'thing': 1, 'happen': 1, 'and': 1, 'go': 1, 'with': 1, 'the': 1, 'moment': 1})
# Counter({'one': 3, 'u': 3, 'a': 3, 'doe': 2, 'make': 2, 'b': 1, 'sew': 1, 'button': 1, 'tailor': 1, 'cook': 1, 'meal': 1, 'chef': 1, 'but': 1, 'hors': 1, 'and': 1, 'r': 1, 'for': 1, 'all': 1, 'of': 1, 'histori': 1})
# Counter({'b': 1, 'Am': 1, 'read': 1, 'robert': 1, 'massi': 1, 'book': 1, 'on': 1, 'catherin': 1, 'the': 1, 'great': 1, 'yeah': 1, 'I': 1, 'know': 1, 'what': 1, 'you': 1, 'probabl': 1, 'think': 1, 'did': 1, 'she': 1, 'realli': 1, 'a': 1, 'hors': 1})
# Counter({'not': 1, 'say': 1, 'that': 1, 'is': 1, 'good': 1, 'or': 1, 'bad': 1, 'but': 1, 'realiti': 1, 'will': 1, 'forc': 1, 'us': 1, 'to': 1, 'live': 1, 'with': 1, 'the': 1, 'consequ': 1, 'of': 1, 'our': 1, 'action': 1, 'http': 1})
# Counter({'b': 1, 'interest': 1, 'economist': 1, 'articl': 1, 'about': 1, 'how': 1, 'human': 1, 'collect': 1, 'action': 1, 'have': 1, 'creat': 1, 'a': 1, 'fundament': 1, 'new': 1, 'geolog': 1, 'age': 1, 'the': 1, 'anthropocen': 1})
# Counter({'b': 1, 'om': 1, 'cool': 1, 'person': 1, 'essay': 1, 'It': 1, 'realli': 1, 'reson': 1, 'with': 1, 'me': 1, 'as': 1, 'I': 1, 'felt': 1, 'the': 1, 'same': 1, 'way': 1, 'after': 1, 'come': 1, 'veri': 1, 'close': 1, 'to': 1, 'die': 1, 'from': 1, 'malaria': 1, 'ten': 1, 'year': 1, 'ago': 1})
# Counter({'as': 2, 'b': 1, 'richardbranson': 1, 'like': 1, 'screw': 1, 'busi': 1, 'usual': 1, 'a': 1, 'lot': 1, 'thi': 1, 'approach': 1, 'should': 1, 'be': 1, 'taken': 1, 'to': 1, 'heart': 1, 'by': 1, 'all': 1, 'it': 1, 'realli': 1, 'is': 1, 'the': 1, 'smart': 1, 'move': 1})
# Counter({'for': 2, 'to': 2, 'b': 1, 'kanyewest': 1, 'just': 1, 'return': 1, 'from': 1, 'haiti': 1, 'those': 1, 'who': 1, 'want': 1, 'help': 1, 'I': 1, 'recommend': 1, 'donat': 1, 'msf': 1, 'unicef': 1, 'and': 1, 'artist': 1, 'peac': 1, 'justic': 1})
# Counter({'theonion': 1, 'ani': 1, 'idiot': 1, 'could': 1, 'have': 1, 'come': 1, 'Up': 1, 'with': 1, 'the': 1, 'car': 1, 'http': 1, 'onioninnov': 1})
# Counter({'b': 1, 'theonion': 1, 'So': 1, 'true': 1})
# Counter({'ever': 2, 'the': 2, 'you': 1, 'want': 1, 'to': 1, 'know': 1, 'truth': 1, 'about': 1, 'moon': 1, 'land': 1, 'best': 1, 'onion': 1, 'articl': 1, 'http': 1})
# Counter({'theonion': 1, 'vend': 1, 'machin': 1, 'attend': 1, 'admit': 1, 'select': 1, 'ha': 1, 'chang': 1, 'A': 1, 'lot': 1, 'over': 1, 'the': 1, 'year': 1, 'http': 1, 'onioninnov': 1})
# Counter({'around': 1, 'a': 1, 'neighborhood': 1, 'recent': 1, 'rebuilt': 1, 'with': 1, 'help': 1, 'from': 1, 'apj': 1, 'and': 1, 'other': 1, 'http': 1})
# Counter({'the': 2, 'b': 1, 'It': 1, 'wa': 1, 'xma': 1, 'so': 1, 'we': 1, 'brought': 1, 'present': 1, 'for': 1, 'kid': 1, 'at': 1, 'orphanag': 1, 'they': 1, 'do': 1, 'usual': 1, 'get': 1, 'much': 1, 'http': 1})
# Counter({'and': 2, 'with': 1, 'unicef': 1, 'doctor': 1, 'without': 1, 'border': 1, 'artist': 1, 'for': 1, 'peac': 1, 'justic': 1, 'I': 1, 'support': 1, 'them': 1, 'would': 1, 'recommend': 1, 'other': 1, 'do': 1, 'too': 1})
# Counter({'a': 3, 'lot': 2, 'of': 2, 'return': 1, 'from': 1, 'trip': 1, 'to': 1, 'haiti': 1, 'cover': 1, 'ground': 1, 'and': 1, 'saw': 1, 'mani': 1, 'tough': 1, 'situat': 1, 'they': 1, 'need': 1, 'help': 1})
# Counter({'the': 2, 'charact': 1, 'tweet': 1, 'are': 1, 'ulitm': 1, 'extens': 1, 'of': 1, 'twitmem': 1})
# Counter({'b': 1, 'I': 1})
# Counter({'have': 2, 'russian': 1, 'are': 1, 'some': 1, 'challeng': 1, 'with': 1, 'their': 1, 'rocket': 1, 'too': 1, 'mani': 1, 'of': 1, 'the': 1, 'engin': 1, 'that': 1, 'design': 1, 'them': 1, 'retir': 1, 'http': 1})
# Counter({'had': 1, 'a': 1, 'long': 1, 'and': 1, 'interest': 1, 'convers': 1, 'on': 1, 'mani': 1, 'subject': 1, 'He': 1, 'ha': 1, 'excit': 1, 'idea': 1, 'for': 1, 'extend': 1, 'hi': 1, 'creativ': 1, 'talent': 1, 'beyond': 1, 'music': 1})
# Counter({'stop': 1, 'by': 1, 'the': 1, 'spacex': 1, 'rocket': 1, 'factori': 1, 'today': 1, 'http': 1})
# Counter({'in': 2, 'S': 1, 'option': 1, 'are': 1, 'out': 1, 'perform': 1, 'red': 1, 'and': 1, 'black': 1, 'for': 1, 'me': 1, 'I': 1, 'will': 1, 'deliv': 1, 'my': 1, 'car': 1, 'http': 1})
# Counter({'you': 2, 'sound': 2, 'b': 1, 'Hi': 1, 'I': 1, 'art': 1, 'garfunkel': 1, 'have': 1, 'heard': 1, 'the': 1, 'of': 1, 'silenc': 1, 'becaus': 1, 'know': 1, 'it': 1, 'make': 1, 'a': 1, 'http': 1})
# Counter({'campo': 1, 'invit': 1, 'me': 1, 'to': 1, 'do': 1, 'a': 1, 'guest': 1, 'DJ': 1, 'gig': 1, 'on': 1, 'kcrw': 1, 'hear': 1, 'my': 1, 'random': 1, 'holiday': 1, 'season': 1, 'music': 1, 'select': 1, 'at': 1, 'http': 1})
# Counter({'even': 1, 'better': 1, 'than': 1, 'deep': 1, 'fri': 1, 'butter': 1, 'http': 1})
# Counter({'will': 2, 'thi': 1, 'realli': 1, 'is': 1, 'me': 1, 'as': 1, 'my': 1, 'mom': 1, 'mayemusk': 1, 'sure': 1, 'I': 1, 'can': 1, 'handl': 1, 'just': 1, 'do': 1, 'char': 1, 'missiv': 1, 'put': 1, 'longer': 1, 'thought': 1, 'on': 1})
# Counter({'call': 1, 'randomli': 1, 'by': 1, 'kany': 1, 'west': 1, 'today': 1, 'and': 1, 'receiv': 1, 'a': 1, 'download': 1, 'of': 1, 'hi': 1, 'thought': 1, 'rang': 1, 'from': 1, 'shoe': 1, 'to': 1, 'mose': 1, 'He': 1, 'wa': 1, 'polit': 1, 'but': 1, 'opaqu': 1})
# Counter({'sing': 1, 'and': 1, 'act': 1, 'talent': 1, 'will': 1, 'be': 1, 'sore': 1, 'miss': 1, 'http': 1, 'park': 1, 'sequel': 1, 'come': 1, 'soon': 1})
# Counter({'the': 2, 'b': 1, 'whi': 1, 'doe': 1, 'crowd': 1, 'cri': 1, 'over': 1, 'gloriou': 1, 'leader': 1, 'kim': 1, 'Il': 1, 'sung': 1, 'death': 1, 'fear': 1, 'of': 1, 'be': 1, 'shot': 1, 'may': 1, 'play': 1, 'a': 1, 'role': 1, 'http': 1})
# Counter({'the': 2, 'harri': 1, 'also': 1, 'wrote': 1, 'a': 1, 'nice': 1, 'piec': 1, 'on': 1, 'awesom': 1, 'of': 1, 'hitchen': 1, 'http': 1, 'may': 1, 'good': 1, 'man': 1, 'rip': 1})
# Counter({'ly': 1, 'the': 1, 'new': 1, 'book': 1, 'by': 1, 'my': 1, 'friend': 1, 'sam': 1, 'harri': 1, 'excel': 1, 'cover': 1, 'art': 1, 'and': 1, 'lot': 1, 'of': 1, 'good': 1, 'reason': 1, 'not': 1, 'to': 1, 'lie': 1})
# Counter({'read': 1, 'a': 1, 'great': 1, 'biographi': 1, 'of': 1, 'ben': 1, 'franklin': 1, 'by': 1, 'isaacson': 1, 'highli': 1, 'recommend': 1})
# Counter({'wa': 1, 'a': 1, 'total': 1, 'non': 1, 'sequitur': 1, 'btw': 1})
# Counter({'voltair': 2, 'quot': 1, 'arguabl': 1, 'better': 1, 'than': 1, 'twain': 1, 'hear': 1, 'news': 1, 'of': 1, 'hi': 1, 'own': 1, 'death': 1, 'repli': 1, 'the': 1, 'report': 1, 'were': 1, 'true': 1, 'onli': 1, 'prematur': 1})
# Counter({'I': 2, 'the': 2, 'to': 2, 'b': 1, 'made': 1, 'volum': 1, 'on': 1, 'model': 1, 'S': 1, 'http': 1, 'go': 1, 'now': 1, 'just': 1, 'need': 1, 'work': 1, 'in': 1, 'a': 1, 'miniatur': 1, 'stoneheng': 1})
# Counter({'to': 2, 'on': 2, 'b': 1, 'went': 1, 'iceland': 1, 'sat': 1, 'ride': 1, 'bumper': 1, 'car': 1, 'ice': 1, 'No': 1, 'not': 1, 'the': 1, 'countri': 1, 'vlad': 1, 'rink': 1, 'in': 1, 'van': 1, 'nuy': 1, 'awesom': 1, 'famili': 1, 'fun': 1, 'http': 1})
# Counter({'me': 2, 'ignor': 1, 'prior': 1, 'tweet': 1, 'as': 1, 'that': 1, 'wa': 1, 'someon': 1, 'pretend': 1, 'to': 1, 'be': 1, 'thi': 1, 'is': 1, 'actual': 1})
# (array(['b', 'http', 'tesla', 'exactli', 'base'], dtype='<U15'),
#  array([0.77094575, 1.00585301, 2.29516325, 4.61193298, 5.6415524 ]))

# %% [markdown]
# ### 1.3. Compare the results with the reference implementation of scikit-learn library.

# %% [markdown]
# Now we use the scikit-learn library. As you can see that, the way we do text normalization affects the result. Feel free to further improve upon (OPTIONAL), e.g. https://stackoverflow.com/questions/36182502/add-stemming-support-to-countvectorizer-sklearn

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1,1), min_df = 1, stop_words = 'english', max_features=500)

features = tfidf.fit(original_documents)
corpus_tf_idf = tfidf.transform(original_documents) 

sum_words = corpus_tf_idf.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in tfidf.vocabulary_.items()]
print(sorted(words_freq, key = lambda x: x[1], reverse=True)[:5])
print('testla', corpus_tf_idf[1, features.vocabulary_['tesla']])
# Out:
# [('http', 163.54366542841234), ('https', 151.85039944652075), ('rt', 112.61998731390989), ('tesla', 95.96401470715628), ('xe2', 88.20944486346477)]
# testla 0.3495243100660956

# %% [markdown]
# ### 1.4.  Apply TF-IDF for information retrieval
# We can use the vector representation of documents to implement an information retrieval system. We test with the query $Q$ = "tesla nasa"

# %%
def cosine_similarity(v1,v2):
    return 1 - spatial.distance.cosine(v1, v2)

def search_vec(query, k, vocabulary, stemmer, document_vectors, original_documents):
    q = query.split()
    q = [stemmer.stem(w) for w in q]
    query_vector = vectorize(q, vocabulary, idf_obj)
    
    # TODO: rank the documents by cosine similarity
    scores = []
    index = 0
    for document_vector in document_vectors:
        cur_score = []
        cur_score.append(index)
        index = index + 1
        for v in document_vector:
            cur_score.append(v)
        scores.append(cur_score)

    print('Top-{0} documents'.format(k))
    for i in range(k):
        print(i, original_documents[scores[int(i)][0]])

query = "tesla nasa"
stemmer = PorterStemmer()
search_vec(query, 5, vocabulary, stemmer, document_vectors, original_documents)
# Out:
# Counter({'tesla': 1, 'nasa': 1})
# Top-5 documents
# 0 b'And so the robots spared humanity ... https://t.co/v7JUJQWfCv'
# 1 b"@ForIn2020 @waltmossberg @mims @defcon_5 Exactly. Tesla is absurdly overvalued if based on the past, but that's irr\xe2\x80\xa6 https://t.co/qQcTqkzgMl"
# 2 b'@waltmossberg @mims @defcon_5 Et tu, Walt?'
# 3 b'Stormy weather in Shortville ...'
# 4 b"@DaveLeeBBC @verge Coal is dying due to nat gas fracking. It's basically dead."

# %% [markdown]
# We can also use the scikit-learn library to do the retrieval.

# %%
new_features = tfidf.transform([query])

cosine_similarities = linear_kernel(new_features, corpus_tf_idf).flatten()
related_docs_indices = cosine_similarities.argsort()[::-1]

topk = 5
print('Top-{0} documents'.format(topk))
for i in range(topk):
    print(i, original_documents[related_docs_indices[i]])
# Out:
# Top-5 documents
# 0 b'@ashwin7002 @NASA @faa @AFPAA We have not ruled that out.'
# 1 b"SpaceX could not do this without NASA. Can't express enough appreciation. https://t.co/uQpI60zAV7"
# 2 b'@NASA launched a rocket into the northern lights http://t.co/tR2cSeMV'
# 3 b'Whatever happens today, we could not have done it without @NASA, but errors are ours alone and me most of all.'
# 4 b'RT @NASA: Updated @SpaceX #Dragon #ISS rendezvous times: NASA TV coverage begins Sunday at 3:30amET: http://t.co/qrm0Dz4jPE. Grapple at  ...'
